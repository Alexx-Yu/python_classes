# %% [markdown]
# ### Методы запросов в протоколе HTTP

# %% [markdown]
# ***Метод GET*** запрашивает информацию из указанного источника и не может влиять на его содержимое. Запрос доступен для кэширования данных (то есть для сохранения, восстановления и дальнейшего использования) и добавления в закладки. Длина запроса ограничена (максимальная длина — 2048 символов).
#
# Пример GET-запроса, отправляемого через адресную строку браузера:
# http://site.ru/page.php?name=dima&age=27

# %% [markdown]
# ***Метод POST*** используется для отправки данных, которые могут оказывать влияние на содержимое ресурса. В отличие от метода GET, запросы POST не могут быть кэшированы, они не остаются в истории браузера и их нельзя добавить в закладки. Длина запроса POST не ограничивается.
#
# Пример POST-запроса, отправляемого через форму запроса:
#
#     POST / HTTP/1.0\r\n
#     Host: www.site.ru\r\n
#     Referer: http://www.site.ru/index.html\r\n
#     Cookie: income=1\r\n
#     Content-Type: application/x-www-form-urlencoded\r\n
#     Content-Length: 35\r\n
#     \r\n
#     login=Dima&password=12345

# %%
# Как только библиотека установлена, импортируем её и отправим наш первый запрос 
# к ресурсу Курсы валют ЦБ РФ в XML и JSON. Используем метод get() из библиотеки requests, 
# передав ему соответствующий URL —  https://www.cbr-xml-daily.ru/daily_json.js:

import requests # Импортируем библиотеку requests
from pprint import pprint # Импортируем функцию pprint()
import json

url = 'https://www.cbr-xml-daily.ru/daily_json.js' # Определяем значение URL страницы для запроса
response = requests.get(url) # Делаем GET-запрос к ресурсу и результат ответа сохраняем в переменной response
print(response) # Выводим значение response на экран как объект
print(response.status_code) # Выводим числовое значение response на экран
# Out:
# <Response [200]>
# 200

# %% [markdown]
# Мы получили объект ответа Response, который содержит всю нужную нам информацию. По умолчанию в квадратных скобках на экран выводится код статуса ответа. В данном случае он равен 200 — то есть запрос был корректным и сервер отдал нам нужную информацию. Значение кода статуса 404 означало бы, что страница по указанному адресу не найдена, а значение 403 — что синтаксис GET-запроса неверный.

# %% [markdown]
# ### Задание 3.1
# Вы уже импортировали модуль requests в ваш код. Напишите строку кода, при выполнении которой будет сделан GET-запрос к ресурсу https://www.cbr-xml-daily.ru/daily.xml, а результат ответа будет сохранён в переменной response

# %%
response3 = requests.get('https://www.cbr-xml-daily.ru/daily.xml')

print(response3) # Выводим значение response на экран как объект
print(response3.status_code) # Выводим числовое значение response на экран
# Out:
# <Response [200]>
# 200

# %% [markdown]
# ### Работаем с ответом

# %%
pprint(response.text) # Выводим содержимое атрибута text переменной response на экран
# Out:
# ('{\n'
#  '    "Date": "2022-03-15T11:30:00+03:00",\n'
#  '    "PreviousDate": "2022-03-12T11:30:00+03:00",\n'
#  '    "PreviousURL": '
#  '"\\/\\/www.cbr-xml-daily.ru\\/archive\\/2022\\/03\\/12\\/daily_json.js",\n'
#  '    "Timestamp": "2022-03-14T23:00:00+03:00",\n'
#  '    "Valute": {\n'
#  '        "AUD": {\n'
#  '            "ID": "R01010",\n'
#  '            "NumCode": "036",\n'
#  '            "CharCode": "AUD",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Австралийский доллар",\n'
#  '            "Value": 83.5173,\n'
#  '            "Previous": 85.6374\n'
#  '        },\n'
#  '        "AZN": {\n'
#  '            "ID": "R01020A",\n'
#  '            "NumCode": "944",\n'
#  '            "CharCode": "AZN",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Азербайджанский манат",\n'
#  '            "Value": 67.9384,\n'
#  '            "Previous": 68.8557\n'
#  '        },\n'
#  '        "GBP": {\n'
#  '            "ID": "R01035",\n'
#  '            "NumCode": "826",\n'
#  '            "CharCode": "GBP",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Фунт стерлингов Соединенного королевства",\n'
#  '            "Value": 151.5177,\n'
#  '            "Previous": 153.5635\n'
#  '        },\n'
#  '        "AMD": {\n'
#  '            "ID": "R01060",\n'
#  '            "NumCode": "051",\n'
#  '            "CharCode": "AMD",\n'
#  '            "Nominal": 100,\n'
#  '            "Name": "Армянских драмов",\n'
#  '            "Value": 22.3221,\n'
#  '            "Previous": 22.5229\n'
#  '        },\n'
#  '        "BYN": {\n'
#  '            "ID": "R01090B",\n'
#  '            "NumCode": "933",\n'
#  '            "CharCode": "BYN",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Белорусский рубль",\n'
#  '            "Value": 34.9971,\n'
#  '            "Previous": 35.3055\n'
#  '        },\n'
#  '        "BGN": {\n'
#  '            "ID": "R01100",\n'
#  '            "NumCode": "975",\n'
#  '            "CharCode": "BGN",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Болгарский лев",\n'
#  '            "Value": 65.0863,\n'
#  '            "Previous": 65.9651\n'
#  '        },\n'
#  '        "BRL": {\n'
#  '            "ID": "R01115",\n'
#  '            "NumCode": "986",\n'
#  '            "CharCode": "BRL",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Бразильский реал",\n'
#  '            "Value": 22.6983,\n'
#  '            "Previous": 23.2629\n'
#  '        },\n'
#  '        "HUF": {\n'
#  '            "ID": "R01135",\n'
#  '            "NumCode": "348",\n'
#  '            "CharCode": "HUF",\n'
#  '            "Nominal": 100,\n'
#  '            "Name": "Венгерских форинтов",\n'
#  '            "Value": 33.4868,\n'
#  '            "Previous": 33.939\n'
#  '        },\n'
#  '        "HKD": {\n'
#  '            "ID": "R01200",\n'
#  '            "NumCode": "344",\n'
#  '            "CharCode": "HKD",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Гонконгский доллар",\n'
#  '            "Value": 14.7323,\n'
#  '            "Previous": 14.9312\n'
#  '        },\n'
#  '        "DKK": {\n'
#  '            "ID": "R01215",\n'
#  '            "NumCode": "208",\n'
#  '            "CharCode": "DKK",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Датская крона",\n'
#  '            "Value": 17.095,\n'
#  '            "Previous": 17.3258\n'
#  '        },\n'
#  '        "USD": {\n'
#  '            "ID": "R01235",\n'
#  '            "NumCode": "840",\n'
#  '            "CharCode": "USD",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Доллар США",\n'
#  '            "Value": 115.1963,\n'
#  '            "Previous": 116.7517\n'
#  '        },\n'
#  '        "EUR": {\n'
#  '            "ID": "R01239",\n'
#  '            "NumCode": "978",\n'
#  '            "CharCode": "EUR",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Евро",\n'
#  '            "Value": 127.2343,\n'
#  '            "Previous": 128.9523\n'
#  '        },\n'
#  '        "INR": {\n'
#  '            "ID": "R01270",\n'
#  '            "NumCode": "356",\n'
#  '            "CharCode": "INR",\n'
#  '            "Nominal": 10,\n'
#  '            "Name": "Индийских рупий",\n'
#  '            "Value": 15.0926,\n'
#  '            "Previous": 15.2964\n'
#  '        },\n'
#  '        "KZT": {\n'
#  '            "ID": "R01335",\n'
#  '            "NumCode": "398",\n'
#  '            "CharCode": "KZT",\n'
#  '            "Nominal": 100,\n'
#  '            "Name": "Казахстанских тенге",\n'
#  '            "Value": 22.4903,\n'
#  '            "Previous": 22.8376\n'
#  '        },\n'
#  '        "CAD": {\n'
#  '            "ID": "R01350",\n'
#  '            "NumCode": "124",\n'
#  '            "CharCode": "CAD",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Канадский доллар",\n'
#  '            "Value": 89.8147,\n'
#  '            "Previous": 91.0274\n'
#  '        },\n'
#  '        "KGS": {\n'
#  '            "ID": "R01370",\n'
#  '            "NumCode": "417",\n'
#  '            "CharCode": "KGS",\n'
#  '            "Nominal": 10,\n'
#  '            "Name": "Киргизских сомов",\n'
#  '            "Value": 11.0309,\n'
#  '            "Previous": 11.9527\n'
#  '        },\n'
#  '        "CNY": {\n'
#  '            "ID": "R01375",\n'
#  '            "NumCode": "156",\n'
#  '            "CharCode": "CNY",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Китайский юань",\n'
#  '            "Value": 18.2218,\n'
#  '            "Previous": 18.4678\n'
#  '        },\n'
#  '        "MDL": {\n'
#  '            "ID": "R01500",\n'
#  '            "NumCode": "498",\n'
#  '            "CharCode": "MDL",\n'
#  '            "Nominal": 10,\n'
#  '            "Name": "Молдавских леев",\n'
#  '            "Value": 62.5217,\n'
#  '            "Previous": 63.4175\n'
#  '        },\n'
#  '        "NOK": {\n'
#  '            "ID": "R01535",\n'
#  '            "NumCode": "578",\n'
#  '            "CharCode": "NOK",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Норвежская крона",\n'
#  '            "Value": 12.8646,\n'
#  '            "Previous": 13.0383\n'
#  '        },\n'
#  '        "PLN": {\n'
#  '            "ID": "R01565",\n'
#  '            "NumCode": "985",\n'
#  '            "CharCode": "PLN",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Польский злотый",\n'
#  '            "Value": 26.4145,\n'
#  '            "Previous": 26.7712\n'
#  '        },\n'
#  '        "RON": {\n'
#  '            "ID": "R01585F",\n'
#  '            "NumCode": "946",\n'
#  '            "CharCode": "RON",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Румынский лей",\n'
#  '            "Value": 25.71,\n'
#  '            "Previous": 26.0572\n'
#  '        },\n'
#  '        "XDR": {\n'
#  '            "ID": "R01589",\n'
#  '            "NumCode": "960",\n'
#  '            "CharCode": "XDR",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "СДР (специальные права заимствования)",\n'
#  '            "Value": 159.3464,\n'
#  '            "Previous": 161.812\n'
#  '        },\n'
#  '        "SGD": {\n'
#  '            "ID": "R01625",\n'
#  '            "NumCode": "702",\n'
#  '            "CharCode": "SGD",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Сингапурский доллар",\n'
#  '            "Value": 84.7593,\n'
#  '            "Previous": 85.9037\n'
#  '        },\n'
#  '        "TJS": {\n'
#  '            "ID": "R01670",\n'
#  '            "NumCode": "972",\n'
#  '            "CharCode": "TJS",\n'
#  '            "Nominal": 10,\n'
#  '            "Name": "Таджикских сомони",\n'
#  '            "Value": 95.0614,\n'
#  '            "Previous": 10.3551\n'
#  '        },\n'
#  '        "TRY": {\n'
#  '            "ID": "R01700J",\n'
#  '            "NumCode": "949",\n'
#  '            "CharCode": "TRY",\n'
#  '            "Nominal": 10,\n'
#  '            "Name": "Турецких лир",\n'
#  '            "Value": 78.1294,\n'
#  '            "Previous": 79.1843\n'
#  '        },\n'
#  '        "TMT": {\n'
#  '            "ID": "R01710A",\n'
#  '            "NumCode": "934",\n'
#  '            "CharCode": "TMT",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Новый туркменский манат",\n'
#  '            "Value": 32.9132,\n'
#  '            "Previous": 33.3576\n'
#  '        },\n'
#  '        "UZS": {\n'
#  '            "ID": "R01717",\n'
#  '            "NumCode": "860",\n'
#  '            "CharCode": "UZS",\n'
#  '            "Nominal": 1000,\n'
#  '            "Name": "Узбекских сумов",\n'
#  '            "Value": 10.5423,\n'
#  '            "Previous": 10.7062\n'
#  '        },\n'
#  '        "UAH": {\n'
#  '            "ID": "R01720",\n'
#  '            "NumCode": "980",\n'
#  '            "CharCode": "UAH",\n'
#  '            "Nominal": 10,\n'
#  '            "Name": "Украинских гривен",\n'
#  '            "Value": 38.1758,\n'
#  '            "Previous": 38.6913\n'
#  '        },\n'
#  '        "CZK": {\n'
#  '            "ID": "R01760",\n'
#  '            "NumCode": "203",\n'
#  '            "CharCode": "CZK",\n'
#  '            "Nominal": 10,\n'
#  '            "Name": "Чешских крон",\n'
#  '            "Value": 50.11,\n'
#  '            "Previous": 50.7866\n'
#  '        },\n'
#  '        "SEK": {\n'
#  '            "ID": "R01770",\n'
#  '            "NumCode": "752",\n'
#  '            "CharCode": "SEK",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Шведская крона",\n'
#  '            "Value": 11.8163,\n'
#  '            "Previous": 11.9759\n'
#  '        },\n'
#  '        "CHF": {\n'
#  '            "ID": "R01775",\n'
#  '            "NumCode": "756",\n'
#  '            "CharCode": "CHF",\n'
#  '            "Nominal": 1,\n'
#  '            "Name": "Швейцарский франк",\n'
#  '            "Value": 124.2544,\n'
#  '            "Previous": 125.9322\n'
#  '        },\n'
#  '        "ZAR": {\n'
#  '            "ID": "R01810",\n'
#  '            "NumCode": "710",\n'
#  '            "CharCode": "ZAR",\n'
#  '            "Nominal": 10,\n'
#  '            "Name": "Южноафриканских рэндов",\n'
#  '            "Value": 76.4003,\n'
#  '            "Previous": 77.4318\n'
#  '        },\n'
#  '        "KRW": {\n'
#  '            "ID": "R01815",\n'
#  '            "NumCode": "410",\n'
#  '            "CharCode": "KRW",\n'
#  '            "Nominal": 1000,\n'
#  '            "Name": "Вон Республики Корея",\n'
#  '            "Value": 92.7618,\n'
#  '            "Previous": 94.7891\n'
#  '        },\n'
#  '        "JPY": {\n'
#  '            "ID": "R01820",\n'
#  '            "NumCode": "392",\n'
#  '            "CharCode": "JPY",\n'
#  '            "Nominal": 100,\n'
#  '            "Name": "Японских иен",\n'
#  '            "Value": 99.4486,\n'
#  '            "Previous": 10.0791\n'
#  '        }\n'
#  '    }\n'
#  '}')

# %%
currencies = response.json() # Применяем метод json()
pprint(currencies) # Выводим результат на экран)
# Out:
# {'Date': '2022-03-15T11:30:00+03:00',
#  'PreviousDate': '2022-03-12T11:30:00+03:00',
#  'PreviousURL': '//www.cbr-xml-daily.ru/archive/2022/03/12/daily_json.js',
#  'Timestamp': '2022-03-14T23:00:00+03:00',
#  'Valute': {'AMD': {'CharCode': 'AMD',
#                     'ID': 'R01060',
#                     'Name': 'Армянских драмов',
#                     'Nominal': 100,
#                     'NumCode': '051',
#                     'Previous': 22.5229,
#                     'Value': 22.3221},
#             'AUD': {'CharCode': 'AUD',
#                     'ID': 'R01010',
#                     'Name': 'Австралийский доллар',
#                     'Nominal': 1,
#                     'NumCode': '036',
#                     'Previous': 85.6374,
#                     'Value': 83.5173},
#             'AZN': {'CharCode': 'AZN',
#                     'ID': 'R01020A',
#                     'Name': 'Азербайджанский манат',
#                     'Nominal': 1,
#                     'NumCode': '944',
#                     'Previous': 68.8557,
#                     'Value': 67.9384},
#             'BGN': {'CharCode': 'BGN',
#                     'ID': 'R01100',
#                     'Name': 'Болгарский лев',
#                     'Nominal': 1,
#                     'NumCode': '975',
#                     'Previous': 65.9651,
#                     'Value': 65.0863},
#             'BRL': {'CharCode': 'BRL',
#                     'ID': 'R01115',
#                     'Name': 'Бразильский реал',
#                     'Nominal': 1,
#                     'NumCode': '986',
#                     'Previous': 23.2629,
#                     'Value': 22.6983},
#             'BYN': {'CharCode': 'BYN',
#                     'ID': 'R01090B',
#                     'Name': 'Белорусский рубль',
#                     'Nominal': 1,
#                     'NumCode': '933',
#                     'Previous': 35.3055,
#                     'Value': 34.9971},
#             'CAD': {'CharCode': 'CAD',
#                     'ID': 'R01350',
#                     'Name': 'Канадский доллар',
#                     'Nominal': 1,
#                     'NumCode': '124',
#                     'Previous': 91.0274,
#                     'Value': 89.8147},
#             'CHF': {'CharCode': 'CHF',
#                     'ID': 'R01775',
#                     'Name': 'Швейцарский франк',
#                     'Nominal': 1,
#                     'NumCode': '756',
#                     'Previous': 125.9322,
#                     'Value': 124.2544},
#             'CNY': {'CharCode': 'CNY',
#                     'ID': 'R01375',
#                     'Name': 'Китайский юань',
#                     'Nominal': 1,
#                     'NumCode': '156',
#                     'Previous': 18.4678,
#                     'Value': 18.2218},
#             'CZK': {'CharCode': 'CZK',
#                     'ID': 'R01760',
#                     'Name': 'Чешских крон',
#                     'Nominal': 10,
#                     'NumCode': '203',
#                     'Previous': 50.7866,
#                     'Value': 50.11},
#             'DKK': {'CharCode': 'DKK',
#                     'ID': 'R01215',
#                     'Name': 'Датская крона',
#                     'Nominal': 1,
#                     'NumCode': '208',
#                     'Previous': 17.3258,
#                     'Value': 17.095},
#             'EUR': {'CharCode': 'EUR',
#                     'ID': 'R01239',
#                     'Name': 'Евро',
#                     'Nominal': 1,
#                     'NumCode': '978',
#                     'Previous': 128.9523,
#                     'Value': 127.2343},
#             'GBP': {'CharCode': 'GBP',
#                     'ID': 'R01035',
#                     'Name': 'Фунт стерлингов Соединенного королевства',
#                     'Nominal': 1,
#                     'NumCode': '826',
#                     'Previous': 153.5635,
#                     'Value': 151.5177},
#             'HKD': {'CharCode': 'HKD',
#                     'ID': 'R01200',
#                     'Name': 'Гонконгский доллар',
#                     'Nominal': 1,
#                     'NumCode': '344',
#                     'Previous': 14.9312,
#                     'Value': 14.7323},
#             'HUF': {'CharCode': 'HUF',
#                     'ID': 'R01135',
#                     'Name': 'Венгерских форинтов',
#                     'Nominal': 100,
#                     'NumCode': '348',
#                     'Previous': 33.939,
#                     'Value': 33.4868},
#             'INR': {'CharCode': 'INR',
#                     'ID': 'R01270',
#                     'Name': 'Индийских рупий',
#                     'Nominal': 10,
#                     'NumCode': '356',
#                     'Previous': 15.2964,
#                     'Value': 15.0926},
#             'JPY': {'CharCode': 'JPY',
#                     'ID': 'R01820',
#                     'Name': 'Японских иен',
#                     'Nominal': 100,
#                     'NumCode': '392',
#                     'Previous': 10.0791,
#                     'Value': 99.4486},
#             'KGS': {'CharCode': 'KGS',
#                     'ID': 'R01370',
#                     'Name': 'Киргизских сомов',
#                     'Nominal': 10,
#                     'NumCode': '417',
#                     'Previous': 11.9527,
#                     'Value': 11.0309},
#             'KRW': {'CharCode': 'KRW',
#                     'ID': 'R01815',
#                     'Name': 'Вон Республики Корея',
#                     'Nominal': 1000,
#                     'NumCode': '410',
#                     'Previous': 94.7891,
#                     'Value': 92.7618},
#             'KZT': {'CharCode': 'KZT',
#                     'ID': 'R01335',
#                     'Name': 'Казахстанских тенге',
#                     'Nominal': 100,
#                     'NumCode': '398',
#                     'Previous': 22.8376,
#                     'Value': 22.4903},
#             'MDL': {'CharCode': 'MDL',
#                     'ID': 'R01500',
#                     'Name': 'Молдавских леев',
#                     'Nominal': 10,
#                     'NumCode': '498',
#                     'Previous': 63.4175,
#                     'Value': 62.5217},
#             'NOK': {'CharCode': 'NOK',
#                     'ID': 'R01535',
#                     'Name': 'Норвежская крона',
#                     'Nominal': 1,
#                     'NumCode': '578',
#                     'Previous': 13.0383,
#                     'Value': 12.8646},
#             'PLN': {'CharCode': 'PLN',
#                     'ID': 'R01565',
#                     'Name': 'Польский злотый',
#                     'Nominal': 1,
#                     'NumCode': '985',
#                     'Previous': 26.7712,
#                     'Value': 26.4145},
#             'RON': {'CharCode': 'RON',
#                     'ID': 'R01585F',
#                     'Name': 'Румынский лей',
#                     'Nominal': 1,
#                     'NumCode': '946',
#                     'Previous': 26.0572,
#                     'Value': 25.71},
#             'SEK': {'CharCode': 'SEK',
#                     'ID': 'R01770',
#                     'Name': 'Шведская крона',
#                     'Nominal': 1,
#                     'NumCode': '752',
#                     'Previous': 11.9759,
#                     'Value': 11.8163},
#             'SGD': {'CharCode': 'SGD',
#                     'ID': 'R01625',
#                     'Name': 'Сингапурский доллар',
#                     'Nominal': 1,
#                     'NumCode': '702',
#                     'Previous': 85.9037,
#                     'Value': 84.7593},
#             'TJS': {'CharCode': 'TJS',
#                     'ID': 'R01670',
#                     'Name': 'Таджикских сомони',
#                     'Nominal': 10,
#                     'NumCode': '972',
#                     'Previous': 10.3551,
#                     'Value': 95.0614},
#             'TMT': {'CharCode': 'TMT',
#                     'ID': 'R01710A',
#                     'Name': 'Новый туркменский манат',
#                     'Nominal': 1,
#                     'NumCode': '934',
#                     'Previous': 33.3576,
#                     'Value': 32.9132},
#             'TRY': {'CharCode': 'TRY',
#                     'ID': 'R01700J',
#                     'Name': 'Турецких лир',
#                     'Nominal': 10,
#                     'NumCode': '949',
#                     'Previous': 79.1843,
#                     'Value': 78.1294},
#             'UAH': {'CharCode': 'UAH',
#                     'ID': 'R01720',
#                     'Name': 'Украинских гривен',
#                     'Nominal': 10,
#                     'NumCode': '980',
#                     'Previous': 38.6913,
#                     'Value': 38.1758},
#             'USD': {'CharCode': 'USD',
#                     'ID': 'R01235',
#                     'Name': 'Доллар США',
#                     'Nominal': 1,
#                     'NumCode': '840',
#                     'Previous': 116.7517,
#                     'Value': 115.1963},
#             'UZS': {'CharCode': 'UZS',
#                     'ID': 'R01717',
#                     'Name': 'Узбекских сумов',
#                     'Nominal': 1000,
#                     'NumCode': '860',
#                     'Previous': 10.7062,
#                     'Value': 10.5423},
#             'XDR': {'CharCode': 'XDR',
#                     'ID': 'R01589',
#                     'Name': 'СДР (специальные права заимствования)',
#                     'Nominal': 1,
#                     'NumCode': '960',
#                     'Previous': 161.812,
#                     'Value': 159.3464},
#             'ZAR': {'CharCode': 'ZAR',
#                     'ID': 'R01810',
#                     'Name': 'Южноафриканских рэндов',
#                     'Nominal': 10,
#                     'NumCode': '710',
#                     'Previous': 77.4318,
#                     'Value': 76.4003}}}

# %%
# Выведем на экран, например, информацию о евро (EUR):
pprint(currencies['Valute']['EUR']) # Выводим на экран информацию о валюте евро
# Out:
# {'CharCode': 'EUR',
#  'ID': 'R01239',
#  'Name': 'Евро',
#  'Nominal': 1,
#  'NumCode': '978',
#  'Previous': 128.9523,
#  'Value': 127.2343}

# %%
print(currencies['Valute']['CZK']['Name'])
# Out:
# Чешских крон

# %% [markdown]
# ### Парсинг сайтов / содержимое веб-страницы / HTML

# %%
import requests # Импортируем библиотеку requests
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url)  # Выполняем GET-запрос
print(response.text)  # Выводим содержимое атрибута text
# Out:
# <!doctype html>
# <html class="no-js bg-fixed _no-bg" style="background-image:url(https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg)" lang="">
# <head>
#
#     <meta charset="utf-8">
#     <meta http-equiv="x-ua-compatible" content="ie=edge">
#     <meta name="viewport" content="width=device-width, initial-scale=1">
#         <meta name="apple-mobile-web-app-capable" content="yes">
#     <meta name="apple-mobile-web-app-status-bar-style" content="black">
#                 <meta name='wmail-verification' content='7991d7eb02d759f05b9050e111a7e3eb' />
#
#     <link rel="canonical" href="https://nplus1.ru/news/2021/10/11/econobel2021" />
#
#     <link rel="icon" href="/i/favicon-bw.png" />
#
#
#         <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
#
#     	    <meta itemprop="datePublished" content="2021-10-11"/>
#
# 	    <meta name="mediator_author" content="Илья Ферапонтов"/>
#
#         <!-- amp page -->
#     <link rel="amphtml" href="https://nplus1.ru/news/2021/10/11/econobel2021/amp">
#
#
#         <!-- for Google -->
#         <meta name="description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#
#         <meta name="author" content="Илья Ферапонтов" />
#         <meta name="copyright" content="" />
#
#         <!-- for Facebook -->
#         <meta property="og:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей" />
#                 <meta property="og:image" content="https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg" />
#         <meta property="og:url" content="https://nplus1.ru/news/2021/10/11/econobel2021" />
#         <meta property="og:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#         <!-- for Twitter -->
#         <meta name="twitter:card" content="summary_large_image">
#         <meta name="twitter:site" content="@nplusodin" />
#         <meta name="twitter:title" content="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей" />
#         <meta name="twitter:description" content="Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. " />
#         <meta name="twitter:image" content="https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg" />
#
#         <meta name="yandex-verification" content="8c90b02c84ac3b72" />
#         <meta name="pmail-verification" content="b419949322895fc9106e24ed01be58ac">
#
#
#         <link rel='alternate' type='application/rss+xml' title='RSS' href='https://nplus1.ru/rss'>
#
#     <link rel="stylesheet" href="/css/font-awesome.min.css">
#     <link rel="stylesheet" href="/css/main.min.css?v=1645705960">
#     <link rel="stylesheet" href="/css/desktop.min.css?v=1452887696">
#     <link rel="stylesheet" href="/css/tablet.min.css?v=1499281342">
#     <link rel="stylesheet" href="/css/mobile.min.css?v=1635965090">
#     <link rel="stylesheet" href="/js/tests/scopus/css/style.css">
#
#             <script src="//ajax.googleapis.com/ajax/libs/jquery/1.11.2/jquery.min.js"></script>
#
#     <script src="//cdnjs.cloudflare.com/ajax/libs/modernizr/2.8.3/modernizr.min.js"></script>
#
#             <script type="text/javascript" src="/js/lib/adfox.asyn.code.ver3.js"> </script>
# 		<script type="text/javascript" src="/js/lib/adfox.asyn.code.scroll.js"> </script>
# 	    <script src="https://yastatic.net/pcode/adfox/loader.js" crossorigin="anonymous"></script>
#         <script async id="__lxGc__rtr" type="text/javascript" src="//s.clickiocdn.com/t/195458/360.js"></script>
#         <script async type="text/javascript" src="//s.luxupcdnc.com/t/common_402.js"></script>
#
# 		<!--  ad -->
# 		<script type="text/javascript">
# 		    var __colAdLoaded = false;
# 		    var __topAdLoaded = false;
#
# 		    var __id = "";
#
# 		    function detectAd(id){
# 		        var _ad = document.getElementById("AdFox_banner_"+id);
# 		    	    console.debug(_ad);
#
# 		        __id = id;
# 		        if(_ad != null && _ad.innerHTML == ""){
# 		            $(".col-ad").remove();
# 		        }
# 		        __colAdLoaded = true;
# 		    }
# 		    function detectAdTop(id){
# 		        __topAdLoaded = true;
# 		    }
# 		</script>
# 		<!-- /ad -->
#
#
#
#
#
# <script type="application/ld+json">{"@context":"http://schema.org","@type":"NewsArticle","mainEntityOfPage":{"@type":"WebPage","@id":"https://nplus1.ru/news/2021/10/11/econobel2021"},"headline":"Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей","description":"Премия присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. ","image":"https://nplus1.ru/images/2021/10/11/7117bddc1d6a6e180ef208ba72511f03.jpg","author":{"@type":"Person","name":"Илья Ферапонтов"},"publisher":{"@type":"Organization","name":"N + 1","logo":{"@type":"ImageObject","url":"https://nplus1.ru/i/logo-alt.png"}},"datePublished":"2021-10-11"}</script>
# </head>
# <body style="background-image:url(https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg)" class="_inner  ">
#
# <div class="shadow-overlay"></div>
# <link property='' rel='stylesheet' href='//s.luxupcdnc.com/cp/all/cookies_policy.css' />
# <script type='text/javascript'>_cookies_policy = {dark:0,bottom:1,text:'Этот сайт использует cookies для улучшения качества работы',link:'Подробнее',href:'https://nplus1.ru/cookies-policy',button:'Закрыть'};</script>
# <script async type='text/javascript' src='//s.luxupcdnc.com/cp/all/cookies_policy.js'></script>
#
#
#
#
#
#
# <div class="thx-rospechat">Функционирует при финансовой поддержке Федерального агентства по печати и массовым коммуникациям (Роспечать)</div>
#
#     <div id="viewport">
# 	<div id="shadow"></div>
#         <div class="ad ad-top">
#
#
#
#
#
#                         	    <!-- bh1 -->
#
#
# <!--AdFox START-->
# <!--yandex_nplus1adv-->
# <!--Площадка: N + 1 / * / *-->
# <!--Тип баннера: Растяжка_100%х250-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_162739969569252320"></div>
# <script>
#     window.yaContextCb.push(()=>{
#         Ya.adfoxCode.create({
#             ownerId: 386110,
#         containerId: 'adfox_162739969569252320',
#             params: {
#                 pp: 'g',
#             ps: 'fbio',
#             p2: 'hhkj'
#             }
#         })
#     })
# </script>
#
#
#
#
#         </div>
#         <header id="header-mobile">
#
#             <div class="container">
#                 <a href="#" class="action-menu pull-left"><i class="icon icon-navicon"></i></a>
#                 <a href="/" class="link-logo"><img src="/i/logo-mobile.png"/></a>
#                 <a href="#" class="action-search pull-right"><i class="icon icon-search"></i></a>
#                 <form action="/search" method="get" class="form-search">
#                     <div class="control">
#                         <input type="text" name="q" placeholder="Найти" value=""/>
#                     </div>
#                     <a href="#" class="action-search-close">×</a>
#                 </form>
#             </div>
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#                                     <li>
#                     <a href="/theme/bookshelf" class="">Книжная полка</a>
#                 </li>
#                             <li>
#                     <a href="/theme/Courses" class="">Курсы</a>
#                 </li>
#                             <li>
#                     <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#                 </li>
#                             <li>
#                     <a href="/theme/offline" class="">N + Offline</a>
#                 </li>
#
#             </ul>
# </nav>
#
#         </header>
#
#
#         <div id="layout" class="js-mediator-container">
#             <!-- header -->
#                         <header id="header" class="_middle">
#     <div class="row">
#
#         <div class="col col-logo">
#             <a href="/" class="link-logo"></a>
#         </div>
#         <div class="col col-nav-main">
#             <form action="/search" method="get" class="form-search">
#                 <div class="control">
#                     <input type="text" name="q" placeholder="Найти" value=""/>
#                 </div>
#                 <a href="#" class="action-search-close">×</a>
#             </form>
#
#             <nav class="nav-rubrics">
#     <ul>
#                 <li>
#             <a href="/rubric/astronomy" class="">Астрономия</a>
#         </li>
#                 <li>
#             <a href="/rubric/physics" class="">Физика</a>
#         </li>
#                 <li>
#             <a href="/rubric/biology" class="">Биология</a>
#         </li>
#                 <li>
#             <a href="/rubric/robots-drones" class="">Роботы и дроны</a>
#         </li>
#
#
#                 <li>
#             <a href="#" class="action-search"><i class="icon icon-search"></i></a>
#         </li>
#             </ul>
# </nav>            <nav class="nav-themes">
#     <ul>
#                 <li data-name="bookshelf">
#             <a href="/theme/bookshelf" class="">Книжная полка</a>
#         </li>
#                 <li data-name="Courses">
#             <a href="/theme/Courses" class="">Курсы</a>
#         </li>
#                 <li data-name="coronavirus-history">
#             <a href="/theme/coronavirus-history" class="">Коронавирусные хроники</a>
#         </li>
#                 <li data-name="offline">
#             <a href="/theme/offline" class="">N + Offline</a>
#         </li>
#             </ul>
# </nav>
#         </div>
#     </div>
#         <div class="container line-up">
#         <div class="line line-second">
#                                             <a href="https://nplus1.ru/blog/2022/03/10/microbes" class="action-line-toggle">
#                     <div class="heading"><span></span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/10/microbes" class="container-link">
#                     <div class="heading"><span>Давайте разберемся</span></div>
#                     <div class="link"><span>Экстренное уничтожение: от каких бактерий избавлялись в украинских лабораториях</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/09/the-new-science-of-human-individuality" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Дэвид Линден &laquo;Почему люди разные: Научный взгляд на человеческую индивидуальность&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/05/an225" class="container-link">
#                     <div class="heading"><span>Авиация</span></div>
#                     <div class="link"><span>Конец &laquo;Мечты&raquo;: о гибели самого большого самолета в мире</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/03/journey-to-the-ants" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Эдвард Уилсон, Берт Хелльдоблер &laquo;Путешествие к муравьям&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/03/01/retoryka-i-marazm-antropocenu" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Эва Бинчик &laquo;Эпоха человека: риторика и апатия антропоцена&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/02/28/four-ladies-and-a-young-man-in-a-vacuum" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Илья Леенсон &laquo;Четыре дамы и молодой человек в вакууме&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/02/25/poisons-around-and-inside" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Сакина Зейналова &laquo;Яды: вокруг и внутри. Путеводитель по самым опасным веществам на планете&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/02/22/blood-and-hematologic-disease" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Михаил Фоминых &laquo;Пять литров красного: Что необходимо знать о крови, ее болезнях и лечении&raquo;</span></div>
#                 </a>
#                                 <a href="https://nplus1.ru/blog/2022/02/17/seeing-into-the-future" class="container-link">
#                     <div class="heading"><span>Книжная полка</span></div>
#                     <div class="link"><span>Мартин Ван Кревельд &laquo;Прозревая будущее: Краткая история предсказаний&raquo;</span></div>
#                 </a>
#                                                 		           	<a href="https://nplus1.ru/blog/2022/03/14/geneweap" class="container-link active">
#         	        	<div class="heading"><span>Давайте разберемся</span></div>
#             	    	<div class="link"><span>Из пушки по генам: что не так с &laquo;этнически ориентированным&raquo; оружием</span></div>
# 		            </a>
#
#             <!-- here -->
#                     </div>
#
#     </div>
#     </header>                        <!-- /header -->
#             <!--  hero -->
#                             <!-- /hero -->
#             <!-- main section -->
#             <section id="main">
#
#
#     <div class="container _middle">
#         <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#             <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                 <article class="content" id="article" data-id="30917" data-visit="1" data-type="0">
#                                         <div class="meta">
#     <div class="tables">
#         <p class="table">
#                         <a data-rubric="economics" href="/rubric/economics">Экономика</a>
#                                                 <a data-theme="nobelprize" href="/theme/nobelprize">Нобелевская премия</a>
#                     </p>
#         <p class="table">
#             <a href="/news/2021/10/11">
#                 <time itemprop="datePublished" content="2021-10-11" data-unix="1633946665">
#                     <span>13:04</span>
#                     <span>11 Окт. 2021</span>
#                 </time>
#             </a>
#         </p>
#         <p class="table">
#             <a href="/difficult/1.1">
#                 <span>Сложность</span>
#                 <span class="difficult-value">1.1</span>
#             </a>
#         </p>
#     </div>
# </div>
# <script type="text/javascript">
#     var _dlData = {custom_rubric: []};
#         _dlData.custom_author = 'Илья Ферапонтов';
#         _dlData.custom_difficult = '1.1';
#         _dlData.custom_rubric.push('Экономика');
#                 _dlData.custom_theme = 'Нобелевская премия';
#
#     window.dataLayer = window.dataLayer || [];
#     window.dataLayer.push(_dlData);
# </script>
#                                         <div class="share-mobile">
#                         <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                     </div>
#
#                     <header class="hero hero-lite">
#                         <div>
#                             <h1>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</h1>
#                         </div>
#                     </header>
#                                         <div class="body js-mediator-article">
#                                                                                                                             <div class="article-image">
#                             <figure>
#                                 <img src="https://nplus1.ru/images/2021/10/11/9c6bcb5f7c01c6d88d49410e16ebc003.jpg"/>
#                                                                                             </figure>
#                         </div>
#
#                                                     <!-- -->
#                                                         <!-- -->
#
#                                                                                             <p>Премия Шведского национального банка по&nbsp;экономическим наукам памяти Альфреда Нобеля за&nbsp;2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов <a href="https://www.nobelprize.org/" target="_blank">шла</a>&nbsp;на&nbsp;официальном сайте Нобелевской премии.</p>
#
# <div class="incut incut-gallery " data-id="30917">
#     <div class="swiper-container">
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <figure>
#                     <div class="img">
#                         <img src="https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg"/>
#                     </div>
#                     <figcaption>
#                     <p class="title">Слева направо: Дэвид Карт, Джошуа Энгрист и Гвидо Имбенс.</p>
#
#                                             	    <p class="credits">Niklas Elmehed © Nobel Prize Outreach</p>
#
#                     </figcaption>
#                 </figure>
#                 <div class="share-incut">
# <div class="title"><i class="fa fa-share"></i><span>Поделиться</span></div>
# <nav class="nav-share">
#     <ul class="social-likes" data-title="Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей">
# 		<li class="facebook" data-service='facebook' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="twitter" data-service='twitter' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="vkontakte" data-service='vkontakte' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
# 		<li class="odnoklassniki" data-service='odnoklassniki' data-image='https://nplus1.ru/images/2021/10/11/b7a9e42f1e5ee878f1d7c50e01bdbe84.jpg', data-description='Niklas Elmehed &copy; Nobel Prize Outreach'></li>
#             </ul>
# </nav>
# </div>
#             </div>
#                     </div>
#         <div class="pagination">
#             <div class="swiper-button-prev"></div>
#             <div class="swiper-counter"></div>
#             <div class="swiper-button-next"></div>
#         </div>
#     </div>
# </div>Премия по&nbsp;экономике, в&nbsp;отличие от&nbsp;Нобелевских премий по&nbsp;физиологии и&nbsp;медицине, физике, химии и&nbsp;литературе, а&nbsp;также премии мира, была учреждена не&nbsp;самим Альфредом Нобелем, а&nbsp;Банком Швеции в&nbsp;1968&nbsp;году. Ее&nbsp;размер равен размеру остальных премий.<p>Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.</p><p>Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.</p><p>Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на&nbsp;основе наукометрических данных, в&nbsp;2021 году <a href="https://nplus1.ru/blog/2021/09/22/clarivate-prognosis-2021" target="_blank">предположила</a>, что в&nbsp;экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и&nbsp;Дэвиду Тису (David Teece) за&nbsp;исследование инноваций.</p>
#
# <p>Кроме того, в&nbsp;списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а&nbsp;также Кармен Рейнхарт (Carmen Reinhart) и&nbsp;Кеннет Рогофф (Kenneth Rogoff)&nbsp;— авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90&nbsp;процентов от&nbsp;ВВП, скорость роста ВВП падает вдвое.</p>
#
# <p>В&nbsp;2020 году премию по&nbsp;экономике присудили Полу Милгрому и&nbsp;Роберту Уилсону за&nbsp;развитие теории аукционов и&nbsp;изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и&nbsp;разрабатывали новые форматы проведения аукционов для продажи товаров и&nbsp;услуг, которые трудно продавать с&nbsp;помощью традиционных методов. Читайте об&nbsp;их&nbsp;работах в&nbsp;нашем материале <a href="https://nplus1.ru/material/2020/10/13/nobel-econ-2020" target="_blank">«Тонкости молотка»</a>.</p>
#
# <p>В 2019 году премии памяти Нобеля по&nbsp;экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и&nbsp;Майкл Кремер&nbsp;— «за&nbsp;экспериментальный подход к&nbsp;искоренению глобальной бедности». Подробнее о&nbsp;заслугах лауреатов можно прочесть в&nbsp;нашем материале&nbsp;<a href="https://nplus1.ru/material/2019/10/14/nobeleconomic" target="_blank" title="Link: https://nplus1.ru/material/2019/10/14/nobeleconomic">«Опыты на&nbsp;бедных»</a>. В&nbsp;2018 года награда была присуждена Уильяму Нордхаусу за&nbsp;«интеграцию изменения климата в&nbsp;долгосрочный макроэкономический анализ» и&nbsp;Полу Ромеру за&nbsp;«интеграцию технологических инноваций в&nbsp;долгосрочный макроэкономический анализ». Об&nbsp;их&nbsp;работах можно прочитать в&nbsp;материале <a href="https://nplus1.ru/material/2018/10/08/econobel-2018" target="_blank">«Почем знания для природы»</a>.</p>
#
# <p><i>Сергей Кузнецов</i></p>
#
#
#
#
#                                             </div>
#                 </article>
#
#
# 				    <!-- ba1 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: мобильный-->
# <div id="adfox_155980540701252236"></div>
# <script>
#     window.Ya.adfoxCode.createAdaptive({
#         ownerId: 248569,
#         containerId: 'adfox_155980540701252236',
#         params: {
#             pp: 'ssg',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     }, ['phone'], {
#         tabletWidth: 1024,
#         phoneWidth: 767,
#         isAutoReloads: false
#     });
# </script>
#
#
# 		                <meter class="bottom"></meter>
#             </div>
#             <div class="col col-1 sidebar" data-adaptive="1" data-tablet-class="col-full">
#                                 <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#
#                                 <div class="ad">
#                                                                 	                            	<!-- ba2 -->
# <!--AdFox START-->
# <!--nplus1_dir-->
# <!--Площадка: https://nplus1.ru/ / * / *-->
# <!--Тип баннера: CLICKIO html5-->
# <!--Расположение: <верх страницы>-->
# <div id="adfox_153934342663011746"></div>
# <script>
#     (function(w, n) {
#     w[n] = w[n] || [];
#     w[n].push({
#         ownerId: 248569,
#         containerId: 'adfox_153934342663011746',
#         params: {
#             pp: 'g',
#             ps: 'cggm',
#             p2: 'fpum',
#             puid1: ''
#         }
#     });})(window, 'adfoxAsyncParams');
# </script>
#
#
#                     	                                                                </div>
#
#
#                 <meter class="top"></meter>
#
#
#
#
#                     <div id="latest" data-adaptive="1" data-tablet-class="fixed" data-mobile-class="fixed">
#
#                         <h2 class="_tablet-hidden _mobile-hidden">Свежее</h2>
#                         <div class="latest-container">
#                         <article class="item item-news item-news-latest-first  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/03/15/achromatic-X-ray-lens" data-id="32526" >
#         <div class="caption">
#                                                                     	                		<img src="https://nplus1.ru/images/2022/03/15/315bd4bad05226802e45bcbf1e880fff.jpg"/>
#
#
#
#                                     <div>
#                         <div class="date">
#                             <span class="name" title="2022-03-15">13:23</span>
#                         </div>
#                         <h3>Физики создали ахроматическую рентгеновскую линзу </h3>
#                     </div>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                                                <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/03/15/leaf-shaped-bifaces" data-id="32522" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-03-15">11:27</span>
#                 </div>
#
#                                     <h3>Отбойник из рога позволил археологам воспроизвести листовидные наконечники</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/03/15/skycourier" data-id="32523" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-03-15">09:53</span>
#                 </div>
#
#                                     <h3>Крупнейший турбовинтовой самолет Cessna получил сертификат типа</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/03/14/Bolt-vs-theropoda" data-id="32516" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-03-14">вчера</span>
#                 </div>
#
#                                     <h3>Усейн Болт оказался быстрее динозавра</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                        <article class="item item-news item-news-  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/03/14/zoonotic-tuberculosis" data-id="32514" >
#         <div class="caption">
#
#
#                                 <div class="date">
#                     <span class="name" title="2022-03-14">вчера</span>
#                 </div>
#
#                                     <h3>Доколумбовые цивилизации Анд пострадали от туберкулеза ластоногих</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                </div>
#
#
#
#
#
#
#                     </div>
#
#
#
#                 </div>
#
#                 <footer class="article-footer">
#                     <div class="row">
#                         <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#                             <p>Нашли опечатку? Выделите фрагмент и нажмите Ctrl+Enter.</p>
#                         </div>
#                         <div class="col col-1 _mobile-hidden _tablet-hidden">
#                             <nav class="nav-share">
#     <ul class="social-likes">
# 		<li class="facebook"></li>
# 		<li class="twitter"></li>
# 		<li class="vkontakte"></li>
# 		<li class="odnoklassniki"></li>
#     </ul>
# </nav>
#                         </div>
#                     </div>
#                 </footer>
#
#                 <div class="ad ad-footer">
#                     			                                                                                        </div>
#
#
#             </div>
#
#
#             <div class="row row-wrap">
#                             </div>
#             <div class="row row-wrap">
#                 <div class="col col-full" data-adaptive="1"  data-mobile-class="col-1">
#
#                                     </div>
#             </div>
#             <div class="row" data-adaptive="1" data-tablet-class="row-wrap" data-mobile-class="row-wrap" data-type="also">
#                 <div class="col col-3" data-adaptive="1" data-mobile-class="col-1">
#
#                                         <section id="also">
#                                                 <h4 class="pull-left">Читайте также</h4>
#                         <div class="col col-also">
#                                                             <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/03/12/hanyusuchus-sinensis" data-id="32499" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/03/10/68b00ef8668111adc6f0412b545e5307.jpg)" class="ill"></div>
#
#
#
#                                     <h3>Гавиал из бронзового века Китая позволил разобраться в родственных связях крокодилов</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/03/14/catalhoyuk" data-id="32507" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/03/11/3db82cb9d69088c3a66f6e671a39ad78.jpg)" class="ill"></div>
#
#
#
#                                     <h3>На останках жителей Чатал-Хююка нашли минеральные пигменты</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                            <article class="item item-news item-news-ill  _exist-image" data-relevance="" data-image="" >
#
#     <a href="/news/2022/03/14/flyzero" data-id="32517" >
#         <div class="caption">
#                             <div style="background-image:url(https://nplus1.ru/images/2022/03/14/71b0bcc3651fe7bd4d02c5fc6f147d77.png)" class="ill"></div>
#
#
#
#                                     <h3>Британцы представили концепты трех водородных самолетов</h3>
#
#
#
#
#
#                                                 </div>
#     </a>
#     </article>                                                    </div>
#
#                     </section>
#                                     </div>
#                 <div class="col col-1" data-adaptive="1" data-tablet-class="col-full _indent-bottom">
#                     <section id="next">
#                         <div class="col col-1" data-adaptive="1" data-tablet-class="col-2">
#                                                         <article class="item item-article item-article-secondary  _exist-image" data-relevance="" data-image="https://nplus1.ru/images/2022/03/14/5c74e007e862afd8b43b007e09f85ad9.jpg" style=background-image:url(https://nplus1.ru/images/2022/03/14/0f167207f7336c916c36527663089416.jpg)>
#
#     <a href="/material/2022/03/14/close-the-door" data-id="32494" >
#         <div class="caption">
#                                                                                     <h3>Двери закрываются</h3>
#                     <p class="subtitle">Наблюдаем, как сворачивается научное сотрудничество с Россией</p>
#                                     </div>
#     </a>
#         <nav class="nav-rubricator">
#         <ul>
#
#                         <li>
#                 <a class="link-rubric" href="/rubric/history">История</a>
#             </li>
#                                     <li>
#                 <a class="link-theme" href="/theme/explainatorium">Давайте разберемся</a>
#             </li>
#                     </ul>
#     </nav>
#     </article>                                                    </div>
#                     </section>
#                 </div>
#             </div>
#         </div>
#     <!--/div-->
#
#     <div id="_mistake">
#         <input type="hidden" name="_token" value="BcCjxEw256t1jU7OcikBrrzAZHMX0yEdhAACFYVo">
#         <input type="hidden" name="id_news" value="30917">
#         <input type="hidden" name="id_author" value="120">
#         <input type="hidden" name="id_editor" value="0">
#     </div>
#     <div id="_post">
#         <input type="hidden" name="_token" value="BcCjxEw256t1jU7OcikBrrzAZHMX0yEdhAACFYVo">
#         <input type="hidden" name="id_news" value="30917">
#     </div>
#             </section>
#             <!-- / main section -->
#
#
#             <div id="wrapper-footer">
#             <section id="difficult" class="_middle">
#     <!-- Slider main container -->
#     <div class="swiper-container">
#         <!-- Additional required wrapper -->
#         <div class="swiper-wrapper">
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">7.7</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/11/moire-exciton">Физики разглядели структуру муарового экситона</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.9</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/10/Fabry-Perot-chemistry">Квантовая интерференция помогла проконтролировать ультрахолодную химическую реакцию</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">6.6</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/14/six-octaves">Частоту магнонов увеличили в 60 раз</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.5</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/10/magnetar-hot-spots">Телескоп NICER увидел движение горячих пятен на магнитаре</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.5</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/10/solar-proton-events">Древесные кольца указали на две древние сверхмощные солнечные вспышки</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.3</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/15/achromatic-X-ray-lens">Физики создали ахроматическую рентгеновскую линзу </a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">5.2</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/10/erosita-bubbles-jet">Астрономы установили возраст пузырей Ферми и eROSITA в центре Млечного Пути</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">4.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/10/ryugu-amino">Планетологи нашли в образцах грунта астероида Рюгу более десяти аминокислот</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">4.8</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/07/parthenogenetic-mice">В Шанхае родились первые полностью партеногенетические мыши</a></h3>
#             </div>
#                         <div class="swiper-slide">
#                 <div class="heading">
#                     <div class="num">
#                         <div class="value">4.7</div>
#                     </div>
#                     <p>Коэффициент сложности</p>
#                 </div>
#                 <h3><a href="/news/2022/03/09/partially-reprogrammed-mice">Частичное репрограммирование позволило частично снизить биологический возраст мышей</a></h3>
#             </div>
#
#         </div>
#         <!-- If we need pagination -->
#         <div class="swiper-pagination"></div>
#         <div class="swiper-button-prev"></div>
#         <div class="swiper-button-next"></div>
#     </div>
#     <h6>Самое сложное</h6>
# </section>
#
#
#             <div class="ad ad-col border">
#                     	    </div>
#
#             <!-- footer -->
#             <footer id="footer">
#     <div class="row" data-adaptive="1" data-middle-class="row-wrap" data-tablet-class="row-wrap" data-mobile-class="row-wrap">
#         <div class="col col-logo">
#             <a href="/" class="link-logo"><img src="/i/logo-alt.png"/></a>
#         </div>
#         <div class="col col-footer-desc">
#             <nav class="nav-pages">
#                 <ul>
#                     <li>
#                         <a href="/about">О нас</a>
#                     </li>
#                     <li>
#                         <a href="https://nplus.pro" target="_blank">N + Production</a>
#                     </li>
#                     <li>
#                         <a href="/adv">Рекламодателям</a>
#                     </li>
#                     <li>
#                         <a href="/rules">Наши материалы</a>
#                     </li>
#                     <li>
#                         <a href="/vacancy">Вакансии</a>
#                     </li>
#                     <li>
#                         <a href="/difficult">Сложность</a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="desc">
#                 <p>&copy; 2022 <i>N&nbsp;+&nbsp;1</i> Интернет-издание &nbsp; Свидетельство о регистрации СМИ Эл № ФС77-67614</p>
#
#                     <p>Использование всех текстовых материалов без изменений в некоммерческих целях разрешается со ссылкой на <i>N&nbsp;+&nbsp;1</i>.
#                         Все аудиовизуальные произведения являются собственностью своих авторов и правообладателей и используются
#                         только в образовательных и информационных целях. Если вы являетесь собственником того или иного произведения
#                         и не согласны с его размещением на нашем сайте, пожалуйста, напишите на kirill@nplus1.ru</p>
#                     <p>Материалы, опубликованные в разделе «Блоги», отражают позиции их авторов, которые могут не совпадать с мнением редакции.</p>
#                     <p>Сайт может содержать контент, не предназначенный для лиц младше 18 лет.</p>
#                     <p>Связь с редакцией: <a href="mailto:info@nplus1.ru">info@nplus1.ru</a></p>
#                     <p>
#                         <a href="https://nplus1.ru/personal-data-policy" class="pd">Политика обработки персональных данных пользователей сайта</a>
#                     </p>
#                     <p>
#                         <script async type="text/javascript" src="//s.luxupcdnc.com/t/consent_195458.js"></script>
#                         <a href="#" onclick="if(window.__lxG__consent__ !== undefined) {window.__lxG__consent__.showConsent()} else {alert('This function works only for users from the European Economic Area (EEA).')}; return false">Change privacy settings</a>
#                     </p>
#
#                 <p>
#                                     </p>
#             </div>
#         </div>
#         <div class="col col-1 pull-right">
#             <nav class="nav-social">
#                 <ul>
#                     <li>
#                         <a href="https://t.me/nplusone"><i class="fa fa-telegram"></i></a>
#                     </li>
#                     <li>
#                         <a href="http://vk.com/nplusone"><i class="fa fa-vk"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://www.facebook.com/nplusone"><i class="fa fa-facebook"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://twitter.com/nplusodin"><i class="fa fa-twitter"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://ok.ru/nplus1"><i class="fa fa-odnoklassniki"></i></a>
#                     </li>
#                     <li>
#                         <a href="https://soundcloud.com/nplus_1"><i class="fa fa-soundcloud"></i></a>
#                     </li>
#                     <li>
#                         <a href="/rss"><i class="fa fa-rss"></i></a>
#                     </li>
#                 </ul>
#             </nav>
#             <div class="partners">
#
#
#                 <!-- Rating@Mail.ru counter -->
# <script type="text/javascript">
# var _tmr = window._tmr || (window._tmr = []);
# _tmr.push({id: "3084572", type: "pageView", start: (new Date()).getTime()});
# (function (d, w, id) {
#   if (d.getElementById(id)) return;
#   var ts = d.createElement("script"); ts.type = "text/javascript"; ts.async = true; ts.id = id;
#   ts.src = "https://top-fwz1.mail.ru/js/code.js";
#   var f = function () {var s = d.getElementsByTagName("script")[0]; s.parentNode.insertBefore(ts, s);};
#   if (w.opera == "[object Opera]") { d.addEventListener("DOMContentLoaded", f, false); } else { f(); }
# })(document, window, "topmailru-code");
# </script><noscript><div>
# <img src="https://top-fwz1.mail.ru/counter?id=3084572;js=na" style="border:0;position:absolute;left:-9999px;" alt="Top.Mail.Ru" />
# </div></noscript>
# <!-- //Rating@Mail.ru counter -->
#
#
#
#             </div>
#         </div>
#     </div>
# </footer>            <!-- / footer -->
#             </div>
#         </div>
#
#     </div>
#
#
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-MNJC58');</script>
# <!-- End Google Tag Manager -->
#
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MNJC58"
# height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) -->
#
#
#
#     <noscript><div><img src="//mc.yandex.ru/watch/29654565" style="position:absolute; left:-9999px;" alt="" /></div></noscript>
#
#
# 	</div>
#
#
#
# <script src="/js/lib/js.cookie.js"></script>
# <script src="/js/lib/jquery.swap.js"></script>
# <script src="/js/lib/swiper.jquery.min.js"></script>
# <script src="/js/lib/svg.js"></script>
# <script src="/js/lib/jquery.mobile-events.min.js"></script>
# <script src="/js/lib/social-likes.min.js"></script>
# <script src="/js/lib/jquery.sticky.js"></script>
# <script src="/js/tests/scopus/js/bundle.js"></script>
#
#
#
# <script src="/js/lib/ts.js"></script>
# <script src="/js/lib/js.cookie.js"></script>
#
#
# <script async src="https://cdn.onthe.io/io.js/QCyUUwp6IVuR"></script>
# <script>
# window._io_config = window._io_config || {};
# window._io_config["0.2.0"] = window._io_config["0.2.0"] || [];
# window._io_config["0.2.0"].push({
#     page_url: document.location.toString(),
#     page_url_canonical: document.querySelector('link[rel="canonical"]').href,
#     page_title: document.querySelector('title').innerHTML,
#     page_type: "article",
#     page_language: "ru",
#     article_authors: [document.querySelector('meta[name="author"]').content || ''],
#     article_publication_date: (new Date(document.querySelector('meta[itemprop="datePublished"]').content).toUTCString()).toString()
# });
# </script>
#
# <!--   project scripts -->
# <script src="/js/main.min.js?v=1643976149"></script>
# <!-- / project scripts -->
#
#
#
#
# <!-- Quantcast Tag -->
# <script type="text/javascript">
# var _qevents = _qevents || [];
#
# (function() {
# var elem = document.createElement('script');
# elem.src = (document.location.protocol == "https:" ? "https://secure" : "http://edge") + ".quantserve.com/quant.js";
# elem.async = true;
# elem.type = "text/javascript";
# var scpt = document.getElementsByTagName('script')[0];
# scpt.parentNode.insertBefore(elem, scpt);
# })();
#
# _qevents.push({
# qacct:"p-s3ftDEFzEW5x7"
# });
# </script>
#
# <noscript>
# <div style="display:none;">
# <img src="//pixel.quantserve.com/pixel/p-s3ftDEFzEW5x7.gif" border="0" height="1" width="1" alt="Quantcast"/>
# </div>
# </noscript>
# <!-- End Quantcast tag -->
# </body>
# </html>

# %% [markdown]
# ### Библиотека BeautifulSoup

# %%
# Устанавливаем библиотеку BeautifulSoup
# !pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/a.y.macbookair/opt/anaconda3/lib/python3.9/site-packages (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /Users/a.y.macbookair/opt/anaconda3/lib/python3.9/site-packages (from beautifulsoup4) (2.2.1)

# %%
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup

# %%
import requests # Импортируем библиотеку requests
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup
url = 'https://nplus1.ru/news/2021/10/11/econobel2021' # Определяем адрес страницы
response = requests.get(url) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер
print(page.title) # Получаем тег title, отображающийся на вкладке браузера
print(page.title.text) # Выводим текст из полученного тега, который содержится в атрибуте text
# Out:
# <title>Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей</title>
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей

# %%
# Извлечем заголовок статьи, опубликованной на этой странице, дату публикации, а также текст статьи.
# Предположим, что мы знаем, что в HTML-коде рассматриваемой нами страницы заголовок статьи заключён 
# в тег <h1> … </h1> (заголовок первого уровня). Тогда мы можем получить его текст с помощью 
# метода find() (с англ. найти) объекта BeautifulSoup, передав ему название интересующего нас тега:

print(page.find('h1').text) # Применяем метод find() к объекту и выводим результат на экран
print(page.find('time').text) # Выводим на экран содержимое атрибута text тега time
# Out:
# Премию Нобеля по экономике присудили за исследования экономики труда и причинно-следственных связей
#
# 13:04
# 11 Окт. 2021

# %% [markdown]
# ###  Задание 5.4
# Напишите функцию wiki_header, которая по адресу страницы возвращает заголовок для статей на Wikipedia.

# %%
import requests
from bs4 import BeautifulSoup

def wiki_header(url):
    response5 = requests.get(url)
    page5 = BeautifulSoup(response5.text, 'html.parser')
    return page5.find('h1').text

wiki_header('https://en.wikipedia.org/wiki/Operating_system')
# 'Operating system'
# Out:
# 'Operating system'

# %% [markdown]
# ### Неуникальные теги: извлекаем текст статьи

# %%
#  текст заключён в тег  <div> … </div> . Попробуем извлечь его уже известным нам способом — 
# с помощью метода find() — и выведем его на экран.
print(page.find('div').text) # Выводим содержимое атрибута text тега div

# %%
# Посмотрим на нашу страницу, используя инструмент разработчика, ещё раз. Можем заметить, 
# что у искомого текста есть свой класс — body js-mediator-article
print(page.find('div', class_='body').text) # Выводим содержимое атрибута text тега div класса body js-mediator-article
# Out:
# Премия Шведского национального банка по экономическим наукам памяти Альфреда Нобеля за 2021 год присуждена Дэвиду Карду (David Card) за его вклад в эмпирические исследования экономики рынка труда, а также Джошуа Энгристу (Joshua Angrist) и Гвидо Имбенсу (Guido Imbens) за их вклад в методологию анализа причинно-следственных связей. Прямая трансляция церемонии объявления лауреатов шла на официальном сайте Нобелевской премии.
#
#
#
#
#
#
#
#
#
# Слева направо: Дэвид Карт, Джошуа Энгрист и Гвидо Имбенс.
# Niklas Elmehed © Nobel Prize Outreach
#
#
#
# Поделиться
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Премия по экономике, в отличие от Нобелевских премий по физиологии и медицине, физике, химии и литературе, а также премии мира, была учреждена не самим Альфредом Нобелем, а Банком Швеции в 1968 году. Ее размер равен размеру остальных премий.Лауреаты этого года награждены за их исследования причинно-следственных связей в области социальных наук. В частности, Дэвид Кард из университета Калифорнии в Беркли начиная с 1990-х годов исследовал, как именно на рынок труда влияют изменения минимальных зарплат, уровень иммиграции и образовательный уровень населения. Полученные им результаты, в частности, указывали, что повышение уровня минимальных зарплат не обязательно влечет за собой сокращение количества рабочих мест.Два других лауреата - Джошуа Ангрист из Массачусетского технологического института и Гвидо Имбенс из Стэнфордского университета исследовали, как можно установить наличие причинно-следственных связей в естественных экспериментах, связанных с поисками отношения между уровнем образования и доходами.Компания Clarivate, которая составляет списки потенциальных нобелевских лауреатов на основе наукометрических данных, в 2021 году предположила, что в экономической номинации премию могут присудить Дэвиду Одречу (David Audretsch) и Дэвиду Тису (David Teece) за исследование инноваций.
# Кроме того, в списке этого года были Джоэл Мокир (Joel Mokyr), который исследует культурные истоки промышленной революции, а также Кармен Рейнхарт (Carmen Reinhart) и Кеннет Рогофф (Kenneth Rogoff) — авторы гипотезы «90-процентного порога»., согласно которой, когда внешний долг государства достигает 90 процентов от ВВП, скорость роста ВВП падает вдвое.
# В 2020 году премию по экономике присудили Полу Милгрому и Роберту Уилсону за развитие теории аукционов и изобретение новых форматов аукционов. Лауреаты исследовали, как работают аукционы, и разрабатывали новые форматы проведения аукционов для продажи товаров и услуг, которые трудно продавать с помощью традиционных методов. Читайте об их работах в нашем материале «Тонкости молотка».
# В 2019 году премии памяти Нобеля по экономике были удостоены Абхиджит Банерджи, Эстер Дюфло и Майкл Кремер — «за экспериментальный подход к искоренению глобальной бедности». Подробнее о заслугах лауреатов можно прочесть в нашем материале «Опыты на бедных». В 2018 года награда была присуждена Уильяму Нордхаусу за «интеграцию изменения климата в долгосрочный макроэкономический анализ» и Полу Ромеру за «интеграцию технологических инноваций в долгосрочный макроэкономический анализ». Об их работах можно прочитать в материале «Почем знания для природы».
# Сергей Кузнецов

# %% [markdown]
# ### Сбор нескольких элементов: собираем все ссылки на странице
# Рассмотрим ещё один сценарий: вы хотите собрать сразу несколько элементов со страницы. Например, представьте, что вы хотите получить названия всех языков программирования, упомянутых на странице в Wikipedia в статье про языки программирования.
#
# Можно заметить, что все названия языков программирования на этой странице связаны ссылками c соответствующими статьями о них. Таким образом, нам необходимо собрать все ссылки на странице. Для ссылок в HTML предусмотрен тег <a> … </a>.

# %%
url = 'https://en.wikipedia.org/wiki/List_of_programming_languages' # Задаём адрес ресурса
response = requests.get(url) # Делаем GET-запрос к ресурсу
page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup
print(page.find('a')) # Ищем ссылку по тегу <a> и выводим её на экран
# Out:
# <a id="top"></a>

# %%
# Мы получили только одну ссылку, хотя на странице их явно больше.
# Это происходит, потому что метод find() возвращает только первый подходящий элемент. 
# Если требуется получить больше элементов, необходимо воспользоваться методом find_all() (с англ. найти все):

links = page.find_all('a') # Ищем все ссылки на странице и сохраняем в переменной links в виде списка
print(len(links)) # Выводим количество найденных ссылок
# Out:
# 936

# %%
print([link.text for link in links[500:510]]) # Выводим ссылки с 500 по 509 включительно
print([link.text for link in links[0:10]]) # Выводим ссылки с 1 по 9 включительно
# Out:
# ['Opal', 'Open Programming Language', 'OpenCL', 'OpenEdge Advanced Business Language', 'OpenVera', 'OPS5', 'OptimJ', 'Orc', 'ORCA/Modula-2', 'Oriel']
# ['', 'Jump to navigation', 'Jump to search', 'Programming languagelists', 'Alphabetical', 'Categorical', 'Chronological', 'Generational', 'v', 't']

# %% [markdown]
# ### Работа с API

# %%
import requests # Импортируем модуль requests
token = '80459d3d80459d3d80459d3d81803e3bbe8804580459d3de275f5e80908a66ed891a8d3' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false,"sex":2,"bdate":"10.10.1984"}]}

# %%
# Словари нагляднее выводить с помощью функции pprint(), которую мы уже использовали ранее:
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %%
print(user['first_name']) # Выводим имя первого пользователя на экран
# Out:
# Павел

# %% [markdown]
# Метод users.get() позволяет запрашивать информацию о множестве (до 1 000) пользователей одновременно. Для этого нужно использовать параметр user_ids и передавать id через запятую в строковом формате. Например, чтобы получить информацию о пользователях с id=1, id=2, id=3, необходимо передать значение параметра user_ids='1,2,3'.

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'last_name': ''}]}

# %% [markdown]
# ###  Задание 6.2
# Используя API, определите долю женщин (sex=1) среди пользователей с id от 1 до 500. Иногда будут попадаться пользователи, у которых пол не указан (sex=0), — таких пользователей не нужно учитывать в общем числе.
#
# В ответе укажите число, округлив до двух знаков после точки-разделителя, например, 0.55.
#
# Пример: если у нас будет 300 пользователей с sex=1, 100 пользователей с sex=2 и 100 пользователей с sex=0, то в ответе должно быть 0.75.

# %%
ids = ",".join(map(str, range(1, 500)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex', 'access_token': token, 'lang': 'ru'}
response6 = requests.get(url, params=params).json()
female = 0
no_gender = 0
for i in range(500-1):
    user_sex = response6['response'][i]['sex']
    if user_sex == 1: female += 1
    if user_sex == 0: no_gender += 1
#print(female,no_gender)
print(round(female / (500 - no_gender),2))
# Out:
# 0.49

# %% [markdown]
# ### Сбор информации из групп
# Обратимся к документации, чтобы узнать, какие методы нам доступны для групп, — для получения списка пользователей группы доступен метод groups.getMembers.
#
# Согласно документации, обязательным параметром данного метода является group_id — идентификатор, или короткое имя, группы. В нашем случае это vk: https://vk.com/vk. Протестируем, как работает метод в самом простом случае, — получим id участников группы:

# %%
import requests # Импортируем модуль requests
token = '80459d3d80459d3d80459d3d81803e3bbe8804580459d3de275f5e80908a66ed891a8d3' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 12385420, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 831, 832, 834, 847, 900, 905, 907, 914, 943, 952, 958, 966, 976, 979, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1290, 1301, 1333, 1334, 1336, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2145, 2150, 2195, 2201, 2202, 2230, 2236, 2273, 2281, 2294, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2515, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2896, 2909, 2919, 2922, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3140, 3172, 3186, 3203, 3213, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3597, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3713, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4150, 4157, 4189, 4192, 4236, 4262, 4282, 4326, 4360, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4625, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4748, 4754, 4767, 4769, 4818, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 4985, 5011, 5017, 5024, 5067, 5073, 5161, 5166, 5183, 5262, 5273, 5280, 5286, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5479, 5481, 5527, 5546, 5547, 5585, 5590, 5606, 5615, 5629, 5634, 5665, 5690, 5701, 5733, 5768, 5775, 5793, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5944, 5959, 5965, 5990, 5991, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6709, 6715, 6797, 6801, 6862, 6950, 6960, 6994, 7012, 7036, 7040, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7188, 7200, 7208, 7226, 7227, 7286, 7290, 7338, 7402, 7404, 7428, 7451, 7481, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7661, 7725, 7737, 7755, 7768, 7777, 7830, 7833, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8066, 8080, 8093, 8149, 8157, 8166, 8167, 8181, 8182, 8194, 8195, 8201, 8224, 8240, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8910, 8937, 8959, 8972, 9000, 9014, 9016, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9319, 9355, 9399, 9412, 9435, 9444, 9447, 9450, 9459, 9466, 9499, 9527, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9954, 9981, 9993, 10010, 10090, 10117, 10155, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11059, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11446, 11451, 11483, 11568, 11649, 11727, 11747, 11754, 11763, 11768, 11782, 11792, 11865, 11964, 11983, 12005, 12029, 12036, 12097, 12133, 12150, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12617, 12625, 12638, 12707, 12716, 12718, 12736, 12748, 12756, 12762, 12803, 12808, 12817, 12859, 12892, 12922, 12932, 12952, 12957, 12 ...

# %%
# По ключу count мы можем получить общее число участников группы, а список по ключу items хранит их id. 
print(len(data['response']['items'])) # Выводим на экран количество элементов словаря
# Out:
# 1000

# %% [markdown]
# Мы видим, что всего пользователей в группе больше 11 миллионов, а получили мы только первую тысячу пользователей группы. По информации, указанной в документации о параметре count, это максимум, который может отдать API за один раз.
#
# Для получения следующей тысячи пользователей можно воспользоваться параметром offset (с англ. смещение), который передвинет начало отсчёта. Для выгрузки всех пользователей группы будем в цикле выгружать по 1000 пользователей (count будет всегда равен 1000), увеличивая смещение offset на величину count.
#
# Для тренировки напишем цикл выгрузки первых 20 пользователей со значением count=5. Иными словами, мы будем выгружать по пять пользователей за запрос до тех пор, пока не получим информацию о 20 пользователях.

# %%
# Давайте выведем на экран первые 20 пользователей из нашей первой попытки получить информацию о 1000 пользователей, 
# чтобы мы могли сверить результат выгрузки из 20 пользователей
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 467, 485, 510, 550, 619, 640, 690]

# %%
# Теперь используем count и offset, чтобы получить те же id по пять за раз:

import requests # Импортируем модуль requests
token = '80459d3d80459d3d80459d3d81803e3bbe8804580459d3de275f5e80908a66ed891a8d3' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 467, 485, 510, 550, 619, 640, 690]

# %%
# Сравним списки, полученные двумя способами:
print(user_ids == users_for_checking)
# Out:
# True

# %% [markdown]
# ### Ограничение по частоте запросов
# В API часто добавляют ограничение по частоте запросов, чтобы отдельно взятые пользователи слишком сильно не перегружали сервер. Подобное ограничение есть и у ВКонтакте — в документации указано, что можно делать не более трёх запросов в секунду.
#
# Чтобы не следить за частотой отправки запросов с секундомером в руках, мы можем после каждого запроса делать паузу. В этом случае, даже если код будет выполняться на самом быстром компьютере, мы не нарушим установленное ограничение, так как периодичность отправки запросов будет искусственно замедлена.
#
# Воспользуемся библиотекой time и методом sleep, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса

# %%
import requests # Импортируем модуль requests
import time # Импортируем модуль time
token = '80459d3d80459d3d80459d3d81803e3bbe8804580459d3de275f5e80908a66ed891a8d3' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset) 
print(user_ids)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 831, 832, 834, 847, 900, 905, 907, 914, 943, 952, 958, 966, 976, 979, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1290, 1301, 1333, 1334, 1336, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 1754, 1796, 1814, 1820, 1829, 1834, 1839, 1840, 1843, 1858, 1863, 1869, 1887, 1889, 1917, 1943, 1947, 1955, 1969, 2019, 2028, 2050, 2051, 2052, 2059, 2077, 2103, 2145, 2150, 2195, 2201, 2202, 2230, 2236, 2273, 2281, 2294, 2296, 2298, 2376, 2389, 2395, 2403, 2412, 2436, 2456, 2466, 2470, 2484, 2515, 2539, 2571, 2576, 2592, 2601, 2622, 2644, 2654, 2692, 2706, 2745, 2755, 2767, 2787, 2797, 2827, 2858, 2896, 2909, 2919, 2922, 2953, 2962, 2982, 3001, 3006, 3041, 3130, 3135, 3140, 3172, 3186, 3203, 3213, 3231, 3250, 3254, 3316, 3320, 3321, 3328, 3331, 3364, 3372, 3373, 3384, 3388, 3402, 3420, 3422, 3427, 3436, 3450, 3458, 3472, 3483, 3486, 3491, 3492, 3520, 3545, 3556, 3581, 3597, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3697, 3713, 3719, 3786, 3820, 3824, 3836, 3837, 3851, 3863, 3904, 3909, 3938, 3948, 3979, 4004, 4010, 4023, 4026, 4041, 4047, 4048, 4108, 4130, 4150, 4157, 4189, 4192, 4236, 4262, 4282, 4326, 4360, 4439, 4440, 4447, 4485, 4505, 4521, 4528, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4625, 4640, 4668, 4669, 4670, 4672, 4689, 4693, 4728, 4731, 4748, 4754, 4767, 4769, 4818, 4857, 4862, 4866, 4881, 4921, 4923, 4928, 4947, 4981, 4985, 5011, 5017, 5024, 5067, 5073, 5161, 5166, 5183, 5262, 5273, 5280, 5286, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5436, 5438, 5472, 5479, 5481, 5527, 5546, 5547, 5585, 5590, 5606, 5615, 5629, 5634, 5665, 5690, 5701, 5733, 5768, 5775, 5793, 5803, 5819, 5846, 5850, 5896, 5914, 5916, 5932, 5944, 5959, 5965, 5990, 5991, 5997, 6000, 6021, 6037, 6046, 6086, 6099, 6107, 6111, 6154, 6161, 6167, 6181, 6186, 6187, 6203, 6260, 6265, 6293, 6323, 6333, 6339, 6379, 6380, 6390, 6492, 6520, 6547, 6557, 6564, 6595, 6604, 6627, 6635, 6670, 6683, 6689, 6701, 6703, 6709, 6715, 6797, 6801, 6862, 6950, 6960, 6994, 7012, 7036, 7040, 7050, 7052, 7068, 7099, 7112, 7115, 7117, 7188, 7200, 7208, 7226, 7227, 7286, 7290, 7338, 7402, 7404, 7428, 7451, 7481, 7492, 7500, 7525, 7543, 7547, 7557, 7595, 7615, 7661, 7725, 7737, 7755, 7768, 7777, 7830, 7833, 7847, 7855, 7858, 7860, 7962, 7982, 7998, 8019, 8066, 8080, 8093, 8149, 8157, 8166, 8167, 8181, 8182, 8194, 8195, 8201, 8224, 8240, 8266, 8273, 8298, 8310, 8321, 8323, 8347, 8348, 8377, 8398, 8418, 8422, 8436, 8443, 8479, 8484, 8505, 8518, 8536, 8544, 8576, 8610, 8636, 8642, 8656, 8658, 8704, 8718, 8727, 8738, 8752, 8777, 8792, 8813, 8875, 8883, 8910, 8937, 8959, 8972, 9000, 9014, 9016, 9079, 9095, 9100, 9110, 9111, 9115, 9173, 9187, 9189, 9222, 9246, 9256, 9319, 9355, 9399, 9412, 9435, 9444, 9447, 9450, 9459, 9466, 9499, 9527, 9532, 9536, 9547, 9556, 9566, 9569, 9571, 9579, 9699, 9723, 9737, 9741, 9748, 9775, 9778, 9782, 9847, 9894, 9900, 9954, 9981, 9993, 10010, 10090, 10117, 10155, 10162, 10217, 10272, 10284, 10286, 10302, 10350, 10351, 10354, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11059, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11446, 11451, 11483, 11568, 11649, 11727, 11747, 11754, 11763, 11768, 11782, 11792, 11865, 11964, 11983, 12005, 12029, 12036, 12097, 12133, 12150, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12617, 12625, 12638, 12707, 12716, 12718, 12736, 12748, 12756, 12762, 12803, 12808, 12817, 12859, 12892, 12922, 12932, 12952, 12957, 12982, 13008, 13063, 13080, 13173, 13224, 13 ...

# %% [markdown]
# ### Лайки, репосты и комментарии
#
# Через API новостной ленты ВКонтакте мы можем получить информацию о взаимодействии с сообщениями в ленте.
#
# Для примера продолжим работать с группой https://vk.com/vk и рассмотрим последние 1000 сообщений в новостной ленте.
#
# Для получения информации о сообщениях на стене в API ВКонтакте предусмотрен метод wall.get.

# %%
import requests # Импортируем модуль requests
from pprint import pprint # Импортируем функцию pprint()
token = '80459d3d80459d3d80459d3d81803e3bbe8804580459d3de275f5e80908a66ed891a8d3' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 471,
#               'items': [{'attachments': [{'photo': {'access_key': 'c3dca019da428da0f5',
#                                                     'album_id': -7,
#                                                     'date': 1647352615,
#                                                     'id': 457329430,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1281405,
#                                                     'sizes': [{'height': 122,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=130x122&quality=96&sign=2c044396476b10c798f34929f758ae06&c_uniq_tag=7xeVurWNqxQsCuTSHP6qbbzrYzX1h7dZ6_tkO0fqA9Q&type=album',
#                                                                'width': 130},
#                                                               {'height': 122,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=130x122&quality=96&sign=2c044396476b10c798f34929f758ae06&c_uniq_tag=7xeVurWNqxQsCuTSHP6qbbzrYzX1h7dZ6_tkO0fqA9Q&type=album',
#                                                                'width': 130},
#                                                               {'height': 188,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=200x188&quality=96&sign=a02ed260d1bef709861fb80d2d1f60a4&c_uniq_tag=FFSPFlO6qw_1cQpxrLz2_kxP5-WpQhUHnM4Hd7IKUI8&type=album',
#                                                                'width': 200},
#                                                               {'height': 300,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=320x300&quality=96&sign=805050a90ea77f9768b5712ddfe576ce&c_uniq_tag=B8rjx88mWLx9DmqbcXPf95KaHZ9wbePYpJUivRSpeXM&type=album',
#                                                                'width': 320},
#                                                               {'height': 478,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=510x478&quality=96&sign=949c5607be3927211e27bac5e777fb1a&c_uniq_tag=vMIfwCJz41Ss3evTLFU2-ZgKJiwYcqHTEyKAX8ngZ7o&type=album',
#                                                                'width': 510},
#                                                               {'height': 70,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=75x70&quality=96&sign=f54149ff9f997d474413f0a499f254c6&c_uniq_tag=hj1RjuGI53wDI4IOgAhREK-DgnPNsX3qOgWmfxmSK0o&type=album',
#                                                                'width': 75},
#                                                               {'height': 2157,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=2300x2157&quality=96&sign=8e3045a0f5f3c753c0b76237ebf39a32&c_uniq_tag=MaSwAoJD8yGETLEdmvdK9PIRhYeXqu50rNzA-TdHRx8&type=album',
#                                                                'width': 2300},
#                                                               {'height': 567,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=604x566&quality=96&sign=df11dcb078708f88df664d1af4fb71c7&c_uniq_tag=YJBgRVsXFO3LbExSDBoFlK-KBJHjWXqf5hyOqODS4kg&type=album',
#                                                                'width': 604},
#                                                               {'height': 757,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=807x757&quality=96&sign=d80b969e0eb31b814eec5c93c7a0191e&c_uniq_tag=EFZsePcT1Hi_Hx8_UnSxqnFxAfY4bjyWA6gXNdj1gp4&type=album',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=1280x1200&quality=96&sign=d44f7f6e996f844ddeb86644a1091097&c_uniq_tag=EUqVjkO4viwW1h2lWuVfAZKHvY40weHkfUxj9YVIYck&type=album',
#                                                                'width': 1152}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 42,
#                                       'groups_can_post': True},
#                          'date': 1647352647,
#                          'from_id': -22822305,
#                          'hash': '2_xZoDsc1CKr3ZSGXA',
#                          'id': 1281405,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 202,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 56, 'user_reposted': 0},
#                          'text': 'В личном кабинете VK ID появился Центр '
#                                  'управления безопасностью: '
#                                  'id.vk.com/account/#/main. В нём можно '
#                                  'оценить уровень защиты своего аккаунта и '
#                                  'узнать, как её усилить. Система даст '
#                                  'персональные советы: например, если пора '
#                                  'сменить пароль.\n'
#                                  '\n'
#                                  'Это обновление — часть нашей программы VK '
#                                  'Protect. Она объединяет технические решения, '
#                                  'которые обеспечивают безопасность во всех '
#                                  'сервисах VK, и понятное руководство в личном '
#                                  'кабинете. Рекомендации, подсказки и FAQ '
#                                  'помогут выбрать и настроить все инструменты '
#                                  'защиты: надёжный пароль, подтверждение входа '
#                                  'и другие.',
#                          'views': {'count': 29757}},
#                         {'attachments': [{'photo': {'access_key': '6f40f97b5fab79e863',
#                                                     'album_id': -7,
#                                                     'date': 1647277442,
#                                                     'id': 457329389,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1280894,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-82/impg/XOngfDQZWm-3r9ZP3F6qIJOQ7s21QSkmjhLM-A/jZiiyfITn_Q.jpg?size=130x130&quality=96&sign=379df294fc7ab6325fad302dfb1345ab&c_uniq_tag=z8ef6jfYeLgbRZtKJCqdGSNHYoGfV-H2CyuTlXeQWCQ&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-82/impg/XOngfDQZWm-3r9ZP3F6qIJOQ7s21QSkmjhLM-A/jZiiyfITn_Q.jpg?size=130x130&quality=96&sign=379df294fc7ab6325fad302dfb1345ab&c_uniq_tag=z8ef6jfYeLgbRZtKJCqdGSNHYoGfV-H2CyuTlXeQWCQ&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-82/impg/XOngfDQZWm-3r9ZP3F6qIJOQ7s21QSkmjhLM-A/jZiiyfITn_Q.jpg?size=200x200&quality=96&sign=fc3ab1320d5b504ff0ee5176450c88a9&c_uniq_tag=EWzixFVJXYJk4sG9IlFIy5v3qhZX4yvik-hDR_kznME&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-82/impg/XOngfDQZWm-3r9ZP3F6qIJOQ7s21QSkmjhLM-A/jZiiyfITn_Q.jpg?size=320x320&quality=96&sign=13bf35503aa49aae0490cb388eabb51d&c_uniq_tag=FBj4rzHR3mYym-1Sa7paG_JEbq5uliii44XaNvpGmDQ&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-82/impg/XOngfDQZWm-3r9ZP3F6qIJOQ7s21QSkmjhLM-A/jZiiyfITn_Q.jpg?size=510x510&quality=96&sign=5e6365b12889628c7d2caee0d1a9d851&c_uniq_tag=wT4Uk0nzWPlF2kHGcWT0rBhos3OFqhvA47bRV2DWT2U&type=album',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-82/impg/XOngfDQZWm-3r9ZP3F6qIJOQ7s21QSkmjhLM-A/jZiiyfITn_Q.jpg?size=75x75&quality=96&sign=0d03252c8a173b74a0be3831eca47fb5&c_uniq_tag=8SHTHVBTS1tVDS4VO3hAtvqjFt4U8FsaxLczWTCR-w8&type=album',
#                                                                'width': 75},
#                                                               {'height': 1480,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-82/impg/XOngfDQZWm-3r9ZP3F6qIJOQ7s21QSkmjhLM-A/jZiiyfITn_Q.jpg?size=1480x1480&quality=96&sign=796f1d8f793582e923788ef6c0c2e13c&c_uniq_tag=-ykU3LxhF9lPVfS8ACUrFgLgfGGkAuuSBcXsEPIsyhI&type=album',
#                                                                'width': 1480},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-82/impg/XOngfDQZWm-3r9ZP3F6qIJOQ7s21QSkmjhLM-A/jZiiyfITn_Q.jpg?size=604x604&quality=96&sign=f52666d54c3c1c958572446ea5ae95ad&c_uniq_tag=hh7qH9djZzQw5gZ-qDkFVu-Q0ysC1fLU4_DP4wiUets&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-82/impg/XOngfDQZWm-3r9ZP3F6qIJOQ7s21QSkmjhLM-A/jZiiyfITn_Q.jpg?size=807x807&quality=96&sign=9f033dce96b7fc2f12877fce2620fdba&c_uniq_tag=l5WXfWKeXx862-xgOhe3Axb5B4Qzs1MorG3JKmVs020&type=album',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-82/impg/XOngfDQZWm-3r9ZP3F6qIJOQ7s21QSkmjhLM-A/jZiiyfITn_Q.jpg?size=1280x1280&quality=96&sign=cd53d281b59d72d447145802c0fbfe57&c_uniq_tag=D2nwMe4PAIvIiJXozeM3iz5W4QOjXScu8Eq7b8C8grA&type=album',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 257,
#                                       'groups_can_post': True},
#                          'date': 1647277497,
#                          'from_id': -22822305,
#                          'hash': 'FO4XcNk2EW1u3l_Gdw',
#                          'id': 1280894,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1091,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 192, 'user_reposted': 0},
#                          'text': 'ВКонтакте стала лидером по объёму '
#                                  'публикуемого контента в феврале и марте 2022 '
#                                  'года. Также социальная сеть возглавила '
#                                  'рейтинг по количеству активных авторов за '
#                                  'день — учитывались пользователи, которые '
#                                  'разместили хотя бы одну публикацию, '
#                                  'комментарий или поделились записью.\n'
#                                  '\n'
#                                  'Подробная информация об исследовании — на '
#                                  'сайте Brand Analytics: vk.cc/cbRv2t.',
#                          'views': {'count': 184097}},
#                         {'attachments': [{'photo': {'access_key': '12b8279bb4f90b2d5d',
#                                                     'album_id': -7,
#                                                     'date': 1647197321,
#                                                     'id': 457329345,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-26/impg/goyiYObZDHSkttrAojreKoASEunEWvofzskR2Q/IVTZWPPJ8-U.jpg?size=130x130&quality=96&sign=6fca7573964e35b62bd4525af1894ee9&c_uniq_tag=v5sDUIKnBSSclalG9kZzXwg_sPADQ7Ws4irIgz7HOxQ&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-26/impg/goyiYObZDHSkttrAojreKoASEunEWvofzskR2Q/IVTZWPPJ8-U.jpg?size=130x130&quality=96&sign=6fca7573964e35b62bd4525af1894ee9&c_uniq_tag=v5sDUIKnBSSclalG9kZzXwg_sPADQ7Ws4irIgz7HOxQ&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-26/impg/goyiYObZDHSkttrAojreKoASEunEWvofzskR2Q/IVTZWPPJ8-U.jpg?size=200x200&quality=96&sign=9c250a178850265b0d559e59369fc5a4&c_uniq_tag=IpV20qANjc3NyR0ptM_D3InrRgJuJEw5myj2JyZ5sGc&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-26/impg/goyiYObZDHSkttrAojreKoASEunEWvofzskR2Q/IVTZWPPJ8-U.jpg?size=320x320&quality=96&sign=69c676488ca66768b8d55413d48fe5fe&c_uniq_tag=3faZkhyT5rl9kMo9ODhzTg9wguX_gvFtK2WzNGuVOQY&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-26/impg/goyiYObZDHSkttrAojreKoASEunEWvofzskR2Q/IVTZWPPJ8-U.jpg?size=510x510&quality=96&sign=d330c1be6e2dde8445accefb4a869763&c_uniq_tag=KCxRbgetEQiUgEad_bt2h8NPtaaANd0KV9bzqQqa9Zc&type=album',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-26/impg/goyiYObZDHSkttrAojreKoASEunEWvofzskR2Q/IVTZWPPJ8-U.jpg?size=75x75&quality=96&sign=3bb192f78ef1d4d0bd2eda3f8ab3a00d&c_uniq_tag=H87TkLYawsc1Ty2cEUn9KPOEgYZxtfwKYD5n9p7INeI&type=album',
#                                                                'width': 75},
#                                                               {'height': 1200,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-26/impg/goyiYObZDHSkttrAojreKoASEunEWvofzskR2Q/IVTZWPPJ8-U.jpg?size=1200x1200&quality=96&sign=ba8e2be6100ce0c400d07ed0f7568d21&c_uniq_tag=Tk8hmOGpKJFocbzTVmUkCZO5GvgZ_PJZO7iaCBPCsAY&type=album',
#                                                                'width': 1200},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-26/impg/goyiYObZDHSkttrAojreKoASEunEWvofzskR2Q/IVTZWPPJ8-U.jpg?size=604x604&quality=96&sign=4bec0bc78bcfd9ce728d9f941756e50c&c_uniq_tag=uLViadJrlyv7MJ_V8rKX9_wvfds14jDhSPK9wlKHygE&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-26/impg/goyiYObZDHSkttrAojreKoASEunEWvofzskR2Q/IVTZWPPJ8-U.jpg?size=807x807&quality=96&sign=3886d5329f3af5aab66ee13e8d89379a&c_uniq_tag=jSbYxVPdzCnkbOIfDwKQSYDftUdBNqemEL_H2bborDc&type=album',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-26/impg/goyiYObZDHSkttrAojreKoASEunEWvofzskR2Q/IVTZWPPJ8-U.jpg?size=1200x1200&quality=96&sign=ba8e2be6100ce0c400d07ed0f7568d21&c_uniq_tag=Tk8hmOGpKJFocbzTVmUkCZO5GvgZ_PJZO7iaCBPCsAY&type=album',
#                                                                'width': 1080}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 560,
#                                       'groups_can_post': True},
#                          'date': 1647194688,
#                          'edited': 1647197321,
#                          'from_id': -22822305,
#                          'hash': 'sb74I0bQR7kVj4NVeg',
#                          'id': 1280192,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 4770,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 7659, 'user_reposted': 0},
#                          'text': 'Обидно терять доступ к своим фотографиям и '
#                                  'видео 💔 Поэтому по вашим просьбам помогаем '
#                                  'сохранить ВКонтакте материалы из Instagram: '
#                                  'vk.com/instagram_manager.\n'
#                                  '\n'
#                                  'Если введёте своё имя пользователя в '
#                                  'Instagram или ссылку на аккаунт, то '
#                                  'перенесутся все фотографии с описаниями. Они '
#                                  'попадут в закрытый альбом «Instagram», но вы '
#                                  'сможете изменить приватность в любой '
#                                  'момент.\n'
#                                  '\n'
#                                  'Ещё рекомендуем успеть скачать из Instagram '
#                                  'архив. Позже с его помощью можно будет '
#                                  'сохранить ВКонтакте ещё и ваши видео (в '
#                                  'раздел «Видео»), а также Reels (в «Клипы»). '
#                                  'Все материалы будут видны только вам.\n'
#                                  '\n'
#                                  'Как скачать архив, а также сделать аккаунт '
#                                  'Instagram открытым, тоже подсказываем в '
#                                  '[vk.com/instagram_manager|приложении].',
#                          'views': {'count': 2855841}},
#                         {'attachments': [{'photo': {'access_key': '1e05736939da6e9a25',
#                                                     'album_id': -7,
#                                                     'date': 1647014395,
#                                                     'id': 457329263,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1279653,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-34/impg/N4rcUP3ap9WQaY_40lx6wZCa8O2RL6JnFN_0Zw/omvWBlKmo0w.jpg?size=75x75&quality=95&sign=cf803f7d6a265bfe4c3f4d555d319476&c_uniq_tag=hHI0I2zDzKPmxGwCH_0JscR3iU2BPuGyGXvthqSxqI4&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-34/impg/N4rcUP3ap9WQaY_40lx6wZCa8O2RL6JnFN_0Zw/omvWBlKmo0w.jpg?size=130x130&quality=95&sign=9adaa22608a2e60f3036a269241f3d68&c_uniq_tag=kXTmsfj4aHF8oqiiMC2iqrOB3qG0N2iFc9l28euMOWo&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-34/impg/N4rcUP3ap9WQaY_40lx6wZCa8O2RL6JnFN_0Zw/omvWBlKmo0w.jpg?size=604x604&quality=95&sign=d72c5f24631697d4ebdd9af89d85a9f0&c_uniq_tag=bYgwFxA73P6wQcY5GObeyx6INYXbIMyqPtY-JLD3OO4&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-34/impg/N4rcUP3ap9WQaY_40lx6wZCa8O2RL6JnFN_0Zw/omvWBlKmo0w.jpg?size=807x807&quality=95&sign=0f8931aa1d7dbfc785e4dd24da93c38b&c_uniq_tag=WCOV2kChyHXenp8VajtzWX_mMSZmZtsievDA7XMigAA&type=album',
#                                                                'width': 807},
#                                                               {'height': 1080,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-34/impg/N4rcUP3ap9WQaY_40lx6wZCa8O2RL6JnFN_0Zw/omvWBlKmo0w.jpg?size=1080x1080&quality=95&sign=0fd72bb20f17739ca39d96a66245b053&c_uniq_tag=of5wxGnK4Obemdi491o8BH7umxne6rwd9GBRyQXsHLM&type=album',
#                                                                'width': 1080},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-34/impg/N4rcUP3ap9WQaY_40lx6wZCa8O2RL6JnFN_0Zw/omvWBlKmo0w.jpg?size=130x130&quality=95&sign=9adaa22608a2e60f3036a269241f3d68&c_uniq_tag=kXTmsfj4aHF8oqiiMC2iqrOB3qG0N2iFc9l28euMOWo&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-34/impg/N4rcUP3ap9WQaY_40lx6wZCa8O2RL6JnFN_0Zw/omvWBlKmo0w.jpg?size=200x200&quality=95&sign=99ae6d6dbd3ebce864c0232bde3e5d0f&c_uniq_tag=JLkmCS6BbAjrS4s8EoMgU0h9qwlKSS-C9zYgPv_Y00A&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-34/impg/N4rcUP3ap9WQaY_40lx6wZCa8O2RL6JnFN_0Zw/omvWBlKmo0w.jpg?size=320x320&quality=95&sign=86373150ff3442349f76ad8b9a8694bf&c_uniq_tag=KyErVb5t2E8lCyrrfNBnzp7TyW8-4GaVFB77y0hPe4k&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-34/impg/N4rcUP3ap9WQaY_40lx6wZCa8O2RL6JnFN_0Zw/omvWBlKmo0w.jpg?size=510x510&quality=95&sign=b36af5881f5b57a839e97e81f93ce22b&c_uniq_tag=NG9kER9EGJrXPNi4sme1q3n90nVK9LVjlzXGQWcWluM&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 226,
#                                       'groups_can_post': True},
#                          'date': 1647014396,
#                          'from_id': -22822305,
#                          'hash': 'DcwC7SrCtrQKsmV7wQ',
#                          'id': 1279653,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 758,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'platform': 'iphone', 'type': 'api'},
#                          'post_type': 'post',
#                          'reposts': {'count': 227, 'user_reposted': 0},
#                          'text': 'ВКонтакте объединяет тысячи талантливых '
#                                  'авторов, которые выбрали нашу платформу для '
#                                  'самовыражения. Мы хотим поддержать их '
#                                  'творчество — для этого запускаем программу '
#                                  'поддержки от Клипов ВКонтакте с призовым '
#                                  'фондом в 100 млн рублей. \n'
#                                  '\n'
#                                  'Чтобы поучаствовать, авторам достаточно '
#                                  'снимать интересные видео и набирать как '
#                                  'можно больше уникальных просмотров. '
#                                  'Программа стартует 11 марта и продлится два '
#                                  'месяца — за это время пройдёт два розыгрыша. '
#                                  'В течение 30 дней команда «Клипов» будет '
#                                  'формировать топ авторов, лучшие из которых '
#                                  'получат награду. Первый этап пройдёт с 11 '
#                                  'марта по 11 апреля, второй — с 12 апреля по '
#                                  '13 мая. \n'
#                                  '\n'
#                                  'Если вы тоже хотите поучаствовать в '
#                                  'программе, заполните анкету: '
#                                  'vk.cc/clippersform. Узнать подробности и '
#                                  'следить за ходом событий можно в сообществе '
#                                  '[club194351072|Клипов ВКонтакте].',
#                          'views': {'count': 254486}},
#                         {'attachments': [{'photo': {'access_key': '9f384e3ecd989f1157',
#                                                     'album_id': -7,
#                                                     'date': 1645434458,
#                                                     'id': 457328488,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1275955,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-50/impg/JG2CM7I4S699NcqHn4OYO8VgYvcL1mMtEEkg3w/rjmFB3IEzBo.jpg?size=75x75&quality=95&sign=869250e20029a670b0ce9ba976d2fc79&c_uniq_tag=cSbFn2DAzYm5tkdYUgqAB29Bb7mdbuImXyaYVC9cB48&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-50/impg/JG2CM7I4S699NcqHn4OYO8VgYvcL1mMtEEkg3w/rjmFB3IEzBo.jpg?size=130x130&quality=95&sign=f00b116efeb348550bc29dfeee641918&c_uniq_tag=EHk8C3_r56X261ybYaVMzvfZ8qZFGmP7OX03RvQnn6o&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-50/impg/JG2CM7I4S699NcqHn4OYO8VgYvcL1mMtEEkg3w/rjmFB3IEzBo.jpg?size=604x604&quality=95&sign=8b37fb6b1acfe1f97d8f8859b18457d7&c_uniq_tag=4Ek7KVw4GANQD_GriC7bhYmZgcd6x2LZcLZj8jdMMTQ&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-50/impg/JG2CM7I4S699NcqHn4OYO8VgYvcL1mMtEEkg3w/rjmFB3IEzBo.jpg?size=807x807&quality=95&sign=cb92b81fee5c39b8877896fb2865d624&c_uniq_tag=Rhvklixc-xTxqdymBwoOChiDmkWw0WWIYKjIr9VzZUc&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-50/impg/JG2CM7I4S699NcqHn4OYO8VgYvcL1mMtEEkg3w/rjmFB3IEzBo.jpg?size=1280x1280&quality=95&sign=b46d381437abea838b2b3c898c373980&c_uniq_tag=c-bVO1cXG8Cf_HFsGJ2W-Dw-gY4elwndkqMadq26Hkk&type=album',
#                                                                'width': 1280},
#                                                               {'height': 2000,
#                                                                'type': 'w',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-50/impg/JG2CM7I4S699NcqHn4OYO8VgYvcL1mMtEEkg3w/rjmFB3IEzBo.jpg?size=2000x2000&quality=95&sign=a446bc191a7462a3866daaf21e57e3c7&c_uniq_tag=RTrCf8WefTxR7TCH14hCrgtr8N56RTBTYLkue05jcS4&type=album',
#                                                                'width': 2000},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-50/impg/JG2CM7I4S699NcqHn4OYO8VgYvcL1mMtEEkg3w/rjmFB3IEzBo.jpg?size=130x130&quality=95&sign=f00b116efeb348550bc29dfeee641918&c_uniq_tag=EHk8C3_r56X261ybYaVMzvfZ8qZFGmP7OX03RvQnn6o&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-50/impg/JG2CM7I4S699NcqHn4OYO8VgYvcL1mMtEEkg3w/rjmFB3IEzBo.jpg?size=200x200&quality=95&sign=1949c34458b2095c20ac1a3c4ec5c96d&c_uniq_tag=0e_KN9UW1z2Zh1UnumHLqlqMXTM-mzxg65dFctdlWRA&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-50/impg/JG2CM7I4S699NcqHn4OYO8VgYvcL1mMtEEkg3w/rjmFB3IEzBo.jpg?size=320x320&quality=95&sign=5dc74a607022b82d30951862ec610c46&c_uniq_tag=lnsCb84Jtql0Ywt-6UZWtWAzHZIX95wCZv0LPqFjD9k&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-50/impg/JG2CM7I4S699NcqHn4OYO8VgYvcL1mMtEEkg3w/rjmFB3IEzBo.jpg?size=510x510&quality=95&sign=9ae573ec32ba246ca0bf8e954979f74e&c_uniq_tag=UtSIeVpyu6SofcwZs7KwwC17YTcvu2Jnoif5nq8kfN4&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 1085,
#                                       'groups_can_post': True},
#                          'date': 1645442003,
#                          'from_id': -22822305,
#                          'hash': 'eQSvKr8_XWclKmCYRw',
#                          'id': 1275955,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 3033,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 1429, 'user_reposted': 0},
#                          'text': 'Продолжаем борьбу со спамом — теперь и за '
#                                  'пределами социальной сети. Всем '
#                                  'пользователям приложения ВКонтакте теперь '
#                                  'доступен автоматический определитель '
#                                  'телефонных номеров. Включите его в '
#                                  'настройках приложения и принимайте только те '
#                                  'звонки, которых ждёте. \n'
#                                  '\n'
#                                  'Сервис подскажет, из какой компании звонят '
#                                  'на телефон, а вызов с подозрительного номера '
#                                  'отметит как нежелательный. Сразу можно будет '
#                                  'понять, когда пора встречать курьера с '
#                                  'пиццей, а когда трубку лучше не брать вовсе. '
#                                  'Определитель бесплатный, работает в фоновом '
#                                  'режиме на iOS и Android и не требует доступа '
#                                  'к сети.',
#                          'views': {'count': 3490359}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': '1563bc5582e5ebbefc',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 1,
#                                                     'can_comment': 0,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 0,
#                                                     'date': 1645012674,
#                                                     'description': '',
#                                                     'duration': 15,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=2329513364049&idx=0&type=39&tkn=l3wkKNWLsFLpjh0l1A83yMvpelo',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=2329513364049&idx=0&type=35&tkn=1kbyN-8Xzd9BgsUbrJKRmglm6R0',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=2329513364049&idx=0&type=34&tkn=BTo9FKH1UcWTGSRaE2EugonW7f0',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=2329513364049&idx=0&type=33&tkn=IVDTQN1N85jnPNDJc_ubvwl_l2c',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=2329513364049&idx=0&type=32&tkn=M3te-q0PP-j2KnU9QjVjoMxIYYM',
#                                                     'height': 1080,
#                                                     'id': 456241261,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=2329513364049&idx=1&type=39&tkn=Jc8hiCq_-qWG2e5Lbmnu6O2PSrs&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=2329513364049&idx=1&type=39&tkn=Jc8hiCq_-qWG2e5Lbmnu6O2PSrs&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=2329513364049&idx=1&type=39&tkn=Jc8hiCq_-qWG2e5Lbmnu6O2PSrs&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=2329513364049&idx=1&type=39&tkn=Jc8hiCq_-qWG2e5Lbmnu6O2PSrs&fn=vid_x',
#                                                     'repeat': 1,
#                                                     'title': 'Лента '
#                                                              '⚡Актуальное',
#                                                     'track_code': 'video_03f85f3coRx_I66D7to4SeaJeCDS7EKM3VYX7VzFfC_3Gs2S0LmRPWEhqeTt2jxM4OJ5FeTedr3vYCbpK6QQQ_c',
#                                                     'views': 765521,
#                                                     'width': 1080}}],
#                          'comments': {'can_post': 1,
#                                       'count': 367,
#                                       'groups_can_post': True},
#                          'date': 1645013076,
#                          'edited': 1645015792,
#                          'from_id': -22822305,
#                          'hash': 'MLktLxz_vTqV1WpmbA',
#                          'id': 1275345,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 981,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 169, 'user_reposted': 0},
#                          'text': 'Хотите узнать, что в мире происходит? '
#                                  'Заглядывайте в ⚡Актуальное — '
#                                  'экспериментальную ленту с главными трендами. '
#                                  'Она покажет полную картину дня и поможет '
#                                  'быть в курсе важного.\n'
#                                  '\n'
#                                  'Ленту формирует специальный алгоритм ⚡. Он '
#                                  'находит и определяет темы с высоким '
#                                  'потенциалом цитируемости и обсуждаемости, а '
#                                  'затем автоматически группирует записи по '
#                                  'тематическим сюжетам. Так что мнения в '
#                                  '⚡Актуальном могут быть полярными — и вы сами '
#                                  'формируете свою позицию. При этом набор '
#                                  'трендов подстраивается под ваши интересы: '
#                                  'например, если увлекаетесь музыкой и кино, '
#                                  'найдёте здесь и обзор свежих релизов, и '
#                                  'последние трейлеры.\n'
#                                  '\n'
#                                  'Ищите ⚡Актуальное в приложении ВКонтакте на '
#                                  'главной, рядом с вкладками «Новости» и «Для '
#                                  'вас». В течение суток лента появится у '
#                                  'всех.\n'
#                                  '\n'
#                                  'Как работают тренды и можно ли попасть в '
#                                  'ленту со своей записью — читайте в блоге: '
#                                  'vk.com/blog/feed-trending',
#                          'views': {'count': 709091}},
#                         {'attachments': [{'photo': {'access_key': '9a3eb434b96e43405f',
#                                                     'album_id': -7,
#                                                     'date': 1644840428,
#                                                     'id': 457328227,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1275041,
#                                                     'sizes': [{'height': 55,
#                                                                'type': 's',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-39/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=75x55&quality=95&sign=7dbab22b23b223b6fba3f4c55d83593a&c_uniq_tag=gIFTj5PP7885O463Y5OUc-RDjxXB40VptvJyc4UH1b0&type=album',
#                                                                'width': 75},
#                                                               {'height': 96,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-39/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=130x96&quality=95&sign=a003f57193eed24abecfd3269fce6ae7&c_uniq_tag=8iJDjHVOvLxrBHyp-RfUXvJeFIBZqZa1D5LPJ3_pRUc&type=album',
#                                                                'width': 130},
#                                                               {'height': 444,
#                                                                'type': 'x',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-39/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=604x444&quality=95&sign=09c2b57b9b669df0c863f97d354c4f97&c_uniq_tag=0XN5IHAmSQH4WfTdPv_szCOOMJjOV30HAT3ZRvPOZIs&type=album',
#                                                                'width': 604},
#                                                               {'height': 593,
#                                                                'type': 'y',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-39/impg/PpwsjqPy_lmiyZYjP6PmMYBVgTa9KbYIuFE_Jg/MKHiXZmygK4.jpg?size=807x593&quality=95&sign=fb9e08a380b4db34a188b30484ded3a1&c_uniq_tag=eePZchS-_wamLUJl3KU0VB5w5BhpKUO2K9l89dAXM2o&type=album',
# ...
#                          'date': 1640174402,
#                          'from_id': -22822305,
#                          'hash': 'IvijjA2qObtzOVtbWA',
#                          'id': 1262935,
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 2328,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 9789, 'user_reposted': 0},
#                          'text': 'Каким был ваш 2021-й ВКонтакте? Точно '
#                                  'особенным — такого года не было ни у кого '
#                                  'больше. Помните, какую песню слушали чаще '
#                                  'всего? А что включали в наушниках прошлой '
#                                  'зимой или летом? С кем подружились, а с кем '
#                                  'общались больше всех? Заходите посмотреть на '
#                                  'свои рекорды и находки — в личных '
#                                  '[https://vk.com/your2021|итогах года].\n'
#                                  '\n'
#                                  'Всеми результатами можно поделиться в '
#                                  'историях и на своей странице — обсуждайте с '
#                                  'друзьями и воспоминайте через год.',
#                          'views': {'count': 1476925}},
#                         {'attachments': [{'photo': {'access_key': 'e6fd3411483c1031ce',
#                                                     'album_id': -7,
#                                                     'date': 1640171386,
#                                                     'id': 457326731,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1262833,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-38/impg/ddj0Ao7X_UNhyoXnCCgZEdHZeAZPAk_WBA8txQ/nzzGzk02Gi4.jpg?size=130x130&quality=96&sign=f04bf2999248d388a6f13de39d1efd1d&c_uniq_tag=5c2boACuXsGAKS31uW8Qs3Mu1LAVeHS8KGFuJZPC4HE&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-38/impg/ddj0Ao7X_UNhyoXnCCgZEdHZeAZPAk_WBA8txQ/nzzGzk02Gi4.jpg?size=130x130&quality=96&sign=f04bf2999248d388a6f13de39d1efd1d&c_uniq_tag=5c2boACuXsGAKS31uW8Qs3Mu1LAVeHS8KGFuJZPC4HE&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun9-54.userapi.com/sun9-38/impg/ddj0Ao7X_UNhyoXnCCgZEdHZeAZPAk_WBA8txQ/nzzGzk02Gi4.jpg?size=200x200&quality=96&sign=0f8b038e4dc52cb5aef72cb1c603d5d7&c_uniq_tag=wAy0tgLg_zk391nCjn70Mm2-K_xAl3nGpU1Okjbp1Sk&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/pc/c2w9pn8d3wd__bfxb8w0bzsh0000gn/T/ipykernel_1237/3669305479.py in <module>
#       5 params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95}
#       6 response = requests.get(url, params = params)
# ----> 7 pprint(response.json())
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in pprint(object, stream, indent, width, depth, compact, sort_dicts)
#      51         stream=stream, indent=indent, width=width, depth=depth,
#      52         compact=compact, sort_dicts=sort_dicts)
# ---> 53     printer.pprint(object)
#      54
#      55 def pformat(object, indent=1, width=80, depth=None, *,
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in pprint(self, object)
#     146
#     147     def pprint(self, object):
# --> 148         self._format(object, self._stream, 0, 0, {}, 0)
#     149         self._stream.write("\n")
#     150
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174             if p is not None:
#     175                 context[objid] = 1
# --> 176                 p(self, object, stream, indent, allowance, context, level + 1)
#     177                 del context[objid]
#     178                 return
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     198             else:
#     199                 items = object.items()
# --> 200             self._format_dict_items(items, stream, indent, allowance + 1,
#     201                                     context, level)
#     202         write('}')
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     381             write(rep)
#     382             write(': ')
# --> 383             self._format(ent, stream, indent + len(rep) + 2,
#     384                          allowance if last else 1,
#     385                          context, level)
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174             if p is not None:
#     175                 context[objid] = 1
# --> 176                 p(self, object, stream, indent, allowance, context, level + 1)
#     177                 del context[objid]
#     178                 return
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     198             else:
#     199                 items = object.items()
# --> 200             self._format_dict_items(items, stream, indent, allowance + 1,
#     201                                     context, level)
#     202         write('}')
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     381             write(rep)
#     382             write(': ')
# --> 383             self._format(ent, stream, indent + len(rep) + 2,
#     384                          allowance if last else 1,
#     385                          context, level)
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174             if p is not None:
#     175                 context[objid] = 1
# --> 176                 p(self, object, stream, indent, allowance, context, level + 1)
#     177                 del context[objid]
#     178                 return
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _pprint_list(self, object, stream, indent, allowance, context, level)
#     219     def _pprint_list(self, object, stream, indent, allowance, context, level):
#     220         stream.write('[')
# --> 221         self._format_items(object, stream, indent, allowance + 1,
#     222                            context, level)
#     223         stream.write(']')
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format_items(self, items, stream, indent, allowance, context, level)
#     424             write(delim)
#     425             delim = delimnl
# --> 426             self._format(ent, stream, indent,
#     427                          allowance if last else 1,
#     428                          context, level)
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174             if p is not None:
#     175                 context[objid] = 1
# --> 176                 p(self, object, stream, indent, allowance, context, level + 1)
#     177                 del context[objid]
#     178                 return
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     198             else:
#     199                 items = object.items()
# --> 200             self._format_dict_items(items, stream, indent, allowance + 1,
#     201                                     context, level)
#     202         write('}')
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     381             write(rep)
#     382             write(': ')
# --> 383             self._format(ent, stream, indent + len(rep) + 2,
#     384                          allowance if last else 1,
#     385                          context, level)
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174             if p is not None:
#     175                 context[objid] = 1
# --> 176                 p(self, object, stream, indent, allowance, context, level + 1)
#     177                 del context[objid]
#     178                 return
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _pprint_list(self, object, stream, indent, allowance, context, level)
#     219     def _pprint_list(self, object, stream, indent, allowance, context, level):
#     220         stream.write('[')
# --> 221         self._format_items(object, stream, indent, allowance + 1,
#     222                            context, level)
#     223         stream.write(']')
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format_items(self, items, stream, indent, allowance, context, level)
#     424             write(delim)
#     425             delim = delimnl
# --> 426             self._format(ent, stream, indent,
#     427                          allowance if last else 1,
#     428                          context, level)
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174             if p is not None:
#     175                 context[objid] = 1
# --> 176                 p(self, object, stream, indent, allowance, context, level + 1)
#     177                 del context[objid]
#     178                 return
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     198             else:
#     199                 items = object.items()
# --> 200             self._format_dict_items(items, stream, indent, allowance + 1,
#     201                                     context, level)
#     202         write('}')
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     381             write(rep)
#     382             write(': ')
# --> 383             self._format(ent, stream, indent + len(rep) + 2,
#     384                          allowance if last else 1,
#     385                          context, level)
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174             if p is not None:
#     175                 context[objid] = 1
# --> 176                 p(self, object, stream, indent, allowance, context, level + 1)
#     177                 del context[objid]
#     178                 return
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     198             else:
#     199                 items = object.items()
# --> 200             self._format_dict_items(items, stream, indent, allowance + 1,
#     201                                     context, level)
#     202         write('}')
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     381             write(rep)
#     382             write(': ')
# --> 383             self._format(ent, stream, indent + len(rep) + 2,
#     384                          allowance if last else 1,
#     385                          context, level)
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174             if p is not None:
#     175                 context[objid] = 1
# --> 176                 p(self, object, stream, indent, allowance, context, level + 1)
#     177                 del context[objid]
#     178                 return
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _pprint_list(self, object, stream, indent, allowance, context, level)
#     219     def _pprint_list(self, object, stream, indent, allowance, context, level):
#     220         stream.write('[')
# --> 221         self._format_items(object, stream, indent, allowance + 1,
#     222                            context, level)
#     223         stream.write(']')
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format_items(self, items, stream, indent, allowance, context, level)
#     424             write(delim)
#     425             delim = delimnl
# --> 426             self._format(ent, stream, indent,
#     427                          allowance if last else 1,
#     428                          context, level)
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format(self, object, stream, indent, allowance, context, level)
#     174             if p is not None:
#     175                 context[objid] = 1
# --> 176                 p(self, object, stream, indent, allowance, context, level + 1)
#     177                 del context[objid]
#     178                 return
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _pprint_dict(self, object, stream, indent, allowance, context, level)
#     198             else:
#     199                 items = object.items()
# --> 200             self._format_dict_items(items, stream, indent, allowance + 1,
#     201                                     context, level)
#     202         write('}')
#
# ~/opt/anaconda3/lib/python3.9/pprint.py in _format_dict_items(self, items, stream, indent, allowance, context, level)
#     379             last = i == last_index
#     380             rep = self._repr(key, context, level)
# --> 381             write(rep)
#     382             write(': ')
#     383             self._format(ent, stream, indent + len(rep) + 2,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py in write(self, string)
#     527             is_child = (not self._is_master_process())
#     528             # only touch the buffer in the IO thread to avoid races
# --> 529             self.pub_thread.schedule(lambda: self._buffer.write(string))
#     530             if is_child:
#     531                 # mp.Pool cannot be trusted to flush promptly (or ever),
#
# ~/opt/anaconda3/lib/python3.9/site-packages/ipykernel/iostream.py in schedule(self, f)
#     212             self._events.append(f)
#     213             # wake event thread (message content is ignored)
# --> 214             self._event_pipe.send(b'')
#     215         else:
#     216             f()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     539                 )
#     540             data.group = group
# --> 541         return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#     542
#     543     def send_multipart(self, msg_parts, flags=0, copy=True, track=False, **kwargs):
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
# Анализируя ответ, понимаем, что по ключу count можно найти общее количество сообщений в новостной ленте, 
# а по ключу items — сами сообщения.
response.json()['response']['items'][0]
# Out:
# {'id': 1281405,
#  'from_id': -22822305,
#  'owner_id': -22822305,
#  'date': 1647352647,
#  'marked_as_ads': 0,
#  'post_type': 'post',
#  'text': 'В личном кабинете VK ID появился Центр управления безопасностью: id.vk.com/account/#/main. В нём можно оценить уровень защиты своего аккаунта и узнать, как её усилить. Система даст персональные советы: например, если пора сменить пароль.\n\nЭто обновление — часть нашей программы VK Protect. Она объединяет технические решения, которые обеспечивают безопасность во всех сервисах VK, и понятное руководство в личном кабинете. Рекомендации, подсказки и FAQ помогут выбрать и настроить все инструменты защиты: надёжный пароль, подтверждение входа и другие.',
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1647352615,
#     'id': 457329430,
#     'owner_id': -22822305,
#     'access_key': 'c3dca019da428da0f5',
#     'post_id': 1281405,
#     'sizes': [{'height': 122,
#       'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=130x122&quality=96&sign=2c044396476b10c798f34929f758ae06&c_uniq_tag=7xeVurWNqxQsCuTSHP6qbbzrYzX1h7dZ6_tkO0fqA9Q&type=album',
#       'type': 'm',
#       'width': 130},
#      {'height': 122,
#       'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=130x122&quality=96&sign=2c044396476b10c798f34929f758ae06&c_uniq_tag=7xeVurWNqxQsCuTSHP6qbbzrYzX1h7dZ6_tkO0fqA9Q&type=album',
#       'type': 'o',
#       'width': 130},
#      {'height': 188,
#       'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=200x188&quality=96&sign=a02ed260d1bef709861fb80d2d1f60a4&c_uniq_tag=FFSPFlO6qw_1cQpxrLz2_kxP5-WpQhUHnM4Hd7IKUI8&type=album',
#       'type': 'p',
#       'width': 200},
#      {'height': 300,
#       'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=320x300&quality=96&sign=805050a90ea77f9768b5712ddfe576ce&c_uniq_tag=B8rjx88mWLx9DmqbcXPf95KaHZ9wbePYpJUivRSpeXM&type=album',
#       'type': 'q',
#       'width': 320},
#      {'height': 478,
#       'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=510x478&quality=96&sign=949c5607be3927211e27bac5e777fb1a&c_uniq_tag=vMIfwCJz41Ss3evTLFU2-ZgKJiwYcqHTEyKAX8ngZ7o&type=album',
#       'type': 'r',
#       'width': 510},
#      {'height': 70,
#       'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=75x70&quality=96&sign=f54149ff9f997d474413f0a499f254c6&c_uniq_tag=hj1RjuGI53wDI4IOgAhREK-DgnPNsX3qOgWmfxmSK0o&type=album',
#       'type': 's',
#       'width': 75},
#      {'height': 2157,
#       'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=2300x2157&quality=96&sign=8e3045a0f5f3c753c0b76237ebf39a32&c_uniq_tag=MaSwAoJD8yGETLEdmvdK9PIRhYeXqu50rNzA-TdHRx8&type=album',
#       'type': 'w',
#       'width': 2300},
#      {'height': 567,
#       'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=604x566&quality=96&sign=df11dcb078708f88df664d1af4fb71c7&c_uniq_tag=YJBgRVsXFO3LbExSDBoFlK-KBJHjWXqf5hyOqODS4kg&type=album',
#       'type': 'x',
#       'width': 604},
#      {'height': 757,
#       'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=807x757&quality=96&sign=d80b969e0eb31b814eec5c93c7a0191e&c_uniq_tag=EFZsePcT1Hi_Hx8_UnSxqnFxAfY4bjyWA6gXNdj1gp4&type=album',
#       'type': 'y',
#       'width': 807},
#      {'height': 1080,
#       'url': 'https://sun9-54.userapi.com/sun9-21/impg/NhImWyiOVZYP2Upg-TzHD1bcDcOaA4TKqzvIqQ/Fop7D01HAtE.jpg?size=1280x1200&quality=96&sign=d44f7f6e996f844ddeb86644a1091097&c_uniq_tag=EUqVjkO4viwW1h2lWuVfAZKHvY40weHkfUxj9YVIYck&type=album',
#       'type': 'z',
#       'width': 1152}],
#     'text': '',
#     'user_id': 100}}],
#  'post_source': {'type': 'vk'},
#  'comments': {'can_post': 1, 'count': 42, 'groups_can_post': True},
#  'likes': {'can_like': 1, 'count': 202, 'user_likes': 0, 'can_publish': 1},
#  'reposts': {'count': 56, 'user_reposted': 0},
#  'views': {'count': 29757},
#  'hash': '2_xZoDsc1CKr3ZSGXA'}

# %%
# В полях comments, likes и reposts содержится статистика по взаимодействию с сообщением пользователей 
# (на момент получения информации) — число комментариев, лайков и репостов. Давайте соберём итоговую статистику 
# для последних десяти непустых сообщений в словарь stats. В качестве ключа будем использовать начало сообщения 
# (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), 
# в качестве значения — список с тремя интересующими нас метриками и временем публикации 
# (комментарии, лайки, репосты, дата публикации)

stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'[https://vk.com/checkback#snow': [1596, 3449, 2013, 1642084584],
#  'В личном кабинете VK ID появил': [42, 202, 56, 1647352647],
#  'ВКонтакте объединяет тысячи та': [226, 758, 227, 1647014396],
#  'ВКонтакте стала лидером по объ': [257, 1091, 192, 1647277497],
#  'День святого Валентина — повод': [202, 824, 192, 1644840943],
#  'Запускаем собственное шоу в пе': [112, 2686, 1532, 1640940328],
#  'Нейросети на страже высокого к': [588, 3299, 1044, 1644258069],
#  'Обидно терять доступ к своим ф': [560, 4770, 7659, 1647194688],
#  'Продолжаем борьбу со спамом — ': [1085, 3033, 1429, 1645442003],
#  'Хотите узнать, что в мире прои': [367, 981, 169, 1645013076]}

# %% [markdown]
# ### Как настроить регулярную выгрузку данных, скрипты

# %%
# Устанавливаем библиотеку schedule
# !pip install schedule
# Out:
# Collecting schedule
#   Downloading schedule-1.1.0-py2.py3-none-any.whl (10 kB)
# Installing collected packages: schedule
# Successfully installed schedule-1.1.0

# %%
import schedule # Импортируем модуль schedule

# %%
# Рассмотрим вариант автоматического запуска простой функции, которая выводит на экран короткое сообщение:

def task(): 
    print('Hello! I am a task!') 
    return

# %%
# Предположим, что мы хотим, чтобы функция запускалась через определённые интервалы времени, а именно каждые 15 минут.
schedule.every(15).minutes.do(task)
# Out:
# Every 15 minutes do task() (last run: [never], next run: 2022-03-15 18:42:33)

# %%
# Если бы мы хотели запускать задачу, например, каждый час, то могли бы написать:
schedule.every(1).hour.do(task)
# Out:
# Every 1 hour do task() (last run: [never], next run: 2022-03-16 15:36:56)

# %% [markdown]
# Мы можем запустить наш менеджер расписания (schedule). Для этого надо создать бесконечный цикл. Скрипт должен выполняться постоянно, чтобы постоянно проверять, не пришло ли время снова выполнить задачу.
#
# Внутри цикла мы будем вызывать особый метод run_pending() для объекта schedule, который будет проверять, нет ли задачи, которую пора выполнить.
#
# После вызова метода run_pending() нужно будет сделать небольшую паузу, после которой можно будет снова проверять, не пришло ли время для выполнения какой-либо функции.
#
# Для создания паузы мы будем использовать метод sleep из модуля time, поэтому наш код начнётся с импорта данного модуля:

# %%
# итоговый код
import schedule

def task(): 
    print('Hello! I am a task!') 
    return

schedule.every(15).minutes.do(task)

import time 
while True: 
    schedule.run_pending() 
    time.sleep(1)
    
# Этот код будет каждую секунду проверять, не надо ли выполнить какую-то задачу, и раз в 15 минут 
# будет выводить на экран фразу: "Hello! I am a task!" Вывод сообщения будет повторяться до тех пор, 
# пока вы не остановите выполнение скрипта
# Out:
# Hello! I am a task!
# Hello! I am a task!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/pc/c2w9pn8d3wd__bfxb8w0bzsh0000gn/T/ipykernel_1237/2313336109.py in <module>
#      11 while True:
#      12     schedule.run_pending()
# ---> 13     time.sleep(1)
#
# KeyboardInterrupt:
